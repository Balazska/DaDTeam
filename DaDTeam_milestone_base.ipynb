# %% [markdown]
# # Milestone III.
#
# Basic training and evaluation process

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
#import seaborn as sns
import numpy as np
import json
import pprint

# %%
"""
GLOVE DOWNLOAD (IF NECESSARY)
"""
# download glove (IT IS NOT NECESSARY IN THE DOCKER CONTAINER, GLOVE IS ALREADY DOWNLOADED THERE)
#!wget "http://nlp.stanford.edu/data/glove.6B.zip" -O temp.zip
#!unzip temp.zip -d glove
#!rm temp.zip
#root_path = ''

"""
ATTACH GLOVE FROM GOOGLE DRIVE (IF YOU HAVE IT)
"""
from google.colab import drive
drive.mount('/content/drive/')
root_path = 'drive/My Drive/Uni/msc_sem4/deeplearning'  #change dir to your project folder
root_path = 'drive/My Drive/msc/dl_hf/' 

"""
IF GLOVE IS STORED IN THE GLOVE FOLDER
"""
# root_path = ''
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# '\nIF GLOVE IS STORED IN THE GLOVE FOLDER\n'

# %%
"""
DOWNLOAD DATA
"""
# !mkdir data
# !wget -c https://smresearchstorage.blob.core.windows.net/smcalflow-public/smcalflow.full.data.tgz -O - | tar -xz -C data
# Out:
# mkdir: cannot create directory ‘data’: File exists
# --2020-12-06 17:15:59--  https://smresearchstorage.blob.core.windows.net/smcalflow-public/smcalflow.full.data.tgz
# Resolving smresearchstorage.blob.core.windows.net (smresearchstorage.blob.core.windows.net)... 52.191.176.36
# Connecting to smresearchstorage.blob.core.windows.net (smresearchstorage.blob.core.windows.net)|52.191.176.36|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13703288 (13M) [application/x-gzip]
# Saving to: ‘STDOUT’
#
# -                   100%[===================>]  13.07M  18.8MB/s    in 0.7s
#
# 2020-12-06 17:16:00 (18.8 MB/s) - written to stdout [13703288/13703288]

# %%
#NOTEBOOK CONTROL VARIABLES

# DO NOT MODIFY
# Model types
MODEL_BILSTM = "bilstm"
MODEL_LSTM = "lstm"

# Run mode
RUN_TESTMODE = "test" # train in 20000 data
RUN_FULLMODE = "full"
# END DO NOT MODIFY

# NOTEBOOK SETTINGS
MODEL_TYPE=MODEL_BILSTM
RUN_MODE=RUN_TESTMODE

# Attention layer, set true to include attention layer
ATTENTION_LAYER = True

HIDDEN_DIM = 128 # for lstm and bilstm mode
# Model fit parameters
BATCH_SIZE=32
EPOCHS=10
# Persist model
PERSIST_MODEL_AS = None # add a filename if you want to save the model at the end
# set False if the data needs to be downloaded
DATA_EXISTS=True

# %%
try:
    from dataflow.core import lispress
except ImportError as error:
    # !pip install git+https://github.com/microsoft/task_oriented_dialogue_as_dataflow_synthesis.git
    print(error)
    from dataflow.core import lispress

# %% [markdown]
# ## Data preprocessing

# %%
import json

# %%
# load train dataset
train = []
with open("data/train.dataflow_dialogues.jsonl") as trainfile:
    content = trainfile.read()
    train = [json.loads(line) for line in content.splitlines()]

# load validation data
valid = []
with open("data/valid.dataflow_dialogues.jsonl") as validfile:
    content = validfile.read()
    valid = [json.loads(line) for line in content.splitlines()]

# %% [markdown]
# ### Tokenization

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
# tokenized_lispress is an external function copied from 
# https://github.com/microsoft/task_oriented_dialogue_as_dataflow_synthesis
# Lispress is the program code to evaluate the answer to a user utturance
# The function tokenizes the lispress input string
from lispress_tokenizer import tokenized_lispress

# %%
# BOS and EOS indicate the beginning and ending of sentences
def tokenizeLispressWithEndings(dataset):
    '''
    Tokenizes lispress of each turn in the given dataset.
    The <bos> and <eos> tokens are appended to the token list.

    Returns nothing since it modifies the dataset
    '''
    for dialog in dataset:
        for turn in dialog["turns"]:
            turn['lispress_tokenized'] = ['<bos>'] + tokenized_lispress(turn['lispress']) + ['<eos>']

# %%
# separate Xpm Xam type string is user utterances

# %%
# create a tokenizer and fit on the sentences of the train data dialogues
tokenizer_user = Tokenizer()
dialogue_sent = [turn['user_utterance']['original_text'] for dialog in train for turn in dialog['turns'] ]
tokenizer_user.fit_on_texts(dialogue_sent)
# index of "the"
tokenizer_user.word_index["the"]
# Out:
# 1

# %%
# create a tokenizer and fit on the tokenized lispress answers of the train data dialogues
lispress_tokenizer = Tokenizer()

# Tokenize lispress in train and valid according to a predefined logic
tokenizeLispressWithEndings(train)
tokenizeLispressWithEndings(valid)

# Tokenizer.fit_on_texts method can take list of list of strings as argument assuming the strings are tokens
dialogue_sent_lispress = [turn['lispress_tokenized'] for dialog in train for turn in dialog['turns']]
lispress_tokenizer.fit_on_texts(dialogue_sent_lispress)

# %%
# Example tokenized lispres
print(dialogue_sent_lispress[1])
print(lispress_tokenizer.word_counts['('])
print(lispress_tokenizer.word_index[')'])
# Out:
# ['<bos>', '(', 'Yield', ':output', '(', ':dayOfWeek', '(', 'Tomorrow', ')', ')', ')', '<eos>']
# 1243286
# 2

# %%
def tokenizeDialogues(dataset,tokenizer):
    """
    Add a tokens2 attribute to the user_utterance in each turn with the token indexes
    Add a tokens2_readable attribute to the user_utterance with the readable tokens
    """
    for dialog in dataset:
        for turn in dialog['turns']:
            seq = tokenizer.texts_to_sequences([turn["user_utterance"]["original_text"]])[0]
            turn["user_utterance"].update({"tokens2":seq,"tokens2_readable":[tokenizer.index_word[index] for index in seq]})
            if "tokens2_variable_readable" in turn["user_utterance"]:
                del turn["user_utterance"]["tokens2_variable_readable"]
    tokenizedSet = [[ turn['user_utterance']['tokens2'] for turn in dialog['turns'] ]for dialog in dataset]
    return tokenizedSet,dataset

def tokenizeLispress(dataset,tokenizer):
    """
    Adds lispress_tokens attribute in each turn which stores the indices of the lispress tokens
    Adds lispress_tokens_readable attribute in each turn which stores the readable tokenized lispress
    """
    for dialog in dataset:
        for turn in dialog['turns']:
            seq = tokenizer.texts_to_sequences([turn["lispress_tokenized"]])[0]
            turn.update({"lispress_tokens":seq,"lispress_tokens_readable":[tokenizer.index_word[index] for index in seq]})
            if "lispress_tokens_variable_readable" in turn:
                del turn["lispress_tokens_variable_readable"]
    tokenizedSet = [[ turn['lispress_tokens'] for turn in dialog['turns'] ]for dialog in dataset]
    return tokenizedSet,dataset

# %%
# Tokenize the user utterance (request) in train and validation set
train_tokenized,train = tokenizeDialogues(train,tokenizer=tokenizer_user)
valid_tokenized,valid = tokenizeDialogues(valid,tokenizer=tokenizer_user)

# %%
# Tokenize the lispress (response) in train and validation set
train_tokenized_lispress,train_lispress = tokenizeLispress(train,tokenizer=lispress_tokenizer)
valid_tokenized_lispress,valid_lispress = tokenizeLispress(valid,tokenizer=lispress_tokenizer)

# %%
def add_parameters(train,train_lispress):
    variable_types = set()

    for di,dialogue in enumerate(train_lispress):
        for ti,turn in enumerate(dialogue["turns"]):
            var_idx={}
            for i,token in enumerate(turn["lispress_tokens_readable"]):
                if not "lispress_tokens_variable_readable" in turn:
                    turn.update({"lispress_tokens_variable_readable": list(turn["lispress_tokens_readable"])})
                if not "tokens2_variable_readable" in train[di]["turns"][ti]["user_utterance"]:
                    train[di]["turns"][ti]["user_utterance"].update({"tokens2_variable_readable":list(train[di]["turns"][ti]["user_utterance"]["tokens2_readable"])})
                if token == "#":
                    variable_expression = turn["lispress_tokens_readable"][i:turn["lispress_tokens_readable"].index(')',i)+1]
                    variable = []
                    var_type = variable_expression[2]
                    variable_types.add(var_type)
                    first = 0
                    last = -1
                    try:
                        first_index = variable_expression.index('"')
                        first = 4
                        last = -2
                    except:
                        first = 3
                        last=-1

                    variable = variable_expression[first:last]

                    for vi,var in enumerate(variable):
                        if var_type == "number":
                            try:
                                var = str(int(float(var)))
                            except Exception as e:
                                print(e)
                        # replace in user utterance
                        if var in train[di]["turns"][ti]["user_utterance"]["tokens2_readable"]:
                            if var_type not in var_idx:
                                var_idx.update({var_type:0})
                                placeholder = "<"+var_type+str(var_idx[var_type])+">"
                                var_idx[var_type]+=1
                                user_idx = train[di]["turns"][ti]["user_utterance"]["tokens2_readable"].index(var)
                                train[di]["turns"][ti]["user_utterance"]["tokens2_variable_readable"][user_idx] = placeholder
                                turn["lispress_tokens_variable_readable"][i+first+vi] = placeholder
                        else:
                            if var_type == "number":
                                for postfix in ["pm","am","th","st","nd"]:
                                    if var+postfix in train[di]["turns"][ti]["user_utterance"]["tokens2_readable"]:
                                        if var_type not in var_idx:
                                            var_idx.update({var_type:0})
                                            placeholder = "<"+var_type+str(var_idx[var_type])+">"
                                            var_idx[var_type]+=1
                                            user_idx = train[di]["turns"][ti]["user_utterance"]["tokens2_readable"].index(var+postfix)
                                            train[di]["turns"][ti]["user_utterance"]["tokens2_variable_readable"][user_idx] = placeholder+postfix
                                            turn["lispress_tokens_variable_readable"][i+first+vi] = placeholder
                            else:
                                print("not found in user utterance:",var,var_type,train[di]["turns"][ti]["user_utterance"]["tokens2_readable"])
                  #print("type:",var_type,"value:",variable)
                  #print("asd")


        #print(turn["lispress_tokens_variable_readable"])
        #print(train[di]["turns"][ti]["user_utterance"]["tokens2_variable_readable"])
    return train, train_lispress, variable_types

# %%
train_params,train_lispress_params,variable_types = add_parameters(train,train_lispress)
# Out:
# A streamkimeneten csak az utolsó 5000 sor látható.
# not found in user utterance: [] list[path] ['can', 'you', 'make', 'it', 'earlier']
# not found in user utterance: start path ['can', 'you', 'make', 'it', 'earlier']
# not found in user utterance: output path ['make', 'my', 'meeting', 'about', '2', 'hours', 'later', 'than', 'stated']
# not found in user utterance: [] list[path] ['make', 'my', 'meeting', 'about', '2', 'hours', 'later', 'than', 'stated']
# not found in user utterance: start path ['make', 'my', 'meeting', 'about', '2', 'hours', 'later', 'than', 'stated']
# not found in user utterance: summarize weatherquantifier ['what', 'is', 'the', 'current', 'humidity', 'in', 'atlanta', 'georgia']
# not found in user utterance: atlanta, locationkeyphrase ['what', 'is', 'the', 'current', 'humidity', 'in', 'atlanta', 'georgia']
# not found in user utterance: uvindex weatherprop ['what', 'is', 'the', 'uv', 'index', 'for', 'the', 'atlanta', 'georgia']
# not found in user utterance: summarize weatherquantifier ['what', 'is', 'the', 'uv', 'index', 'for', 'the', 'atlanta', 'georgia']
# not found in user utterance: atlanta, locationkeyphrase ['what', 'is', 'the', 'uv', 'index', 'for', 'the', 'atlanta', 'georgia']
# not found in user utterance: temperature weatherprop ['sure', 'what', 'is', 'the', 'high', 'for', 'woodstock', 'ga']
# not found in user utterance: max weatherquantifier ['sure', 'what', 'is', 'the', 'high', 'for', 'woodstock', 'ga']
# not found in user utterance: woodstock, locationkeyphrase ['sure', 'what', 'is', 'the', 'high', 'for', 'woodstock', 'ga']
# not found in user utterance: rob personname ['what', 'is', "rob's", 'contact', 'information']
# not found in user utterance: rainprecipprobability weatherprop ['what', 'is', "tomorrow's", 'rain', 'chance']
# not found in user utterance: summarize weatherquantifier ['what', 'is', "tomorrow's", 'rain', 'chance']
# not found in user utterance: henny personname ['can', 'you', 'add', 'an', 'appointment', 'with', "henny's", 'boss', 'at', '10am', 'on', 'tuesday']
# not found in user utterance: output path ['make', 'it', 'until', '11']
# not found in user utterance: output path ['yes', 'add', 'in', 'abby', 'and', 'her', 'boss']
# not found in user utterance: goodforgroups placefeature ['oh', 'great', 'could', 'you', 'tell', 'me', 'if', 'it', 's', 'good', 'for', 'groups']
# not found in user utterance: goodforgroups placefeature ['is', 'it', 'good', 'for', 'big', 'parties']
# not found in user utterance: kenneth personname ['kenneths', 'phone', 'number']
# not found in user utterance: kenneth personname ['kenneths', 'email', 'address']
# not found in user utterance: output path ["let's", 'go', 'with', 'a', '3', 'pm', 'start', 'time']
# not found in user utterance: appointment string ['where', 'was', 'my', "doctor's", "appointment's", 'location', 'for', 'next', 'monday']
# not found in user utterance: mr. personname ['hi', 'schedule', 'an', 'appointment', 'for', '10am', 'tomorrow', 'with', 'mr', 'skinner']
# not found in user utterance: hepsibar personname ['please', 'remove', 'hepisbar', 'from', 'by', 'psychologist', 'appointment', 'tomorrow']
# not found in user utterance: hepsibar personname ['please', 'remove', 'hepisbar', 'from', 'by', 'psychologist', 'appointment', 'tomorrow']
# not found in user utterance: follow-up string ['hepsibar', 'is', 'supposed', 'to', 'attend', 'the', 'follow', 'up', 'meeting', 'on', 'september', '13', 'please', 'delete', 'his', 'name', 'from', 'that', 'meeting', 'too']
# not found in user utterance: abby personname ['do', 'i', 'have', 'a', 'meeting', 'with', 'someone', 'on', "abby's", 'team']
# not found in user utterance: go string ['i', 'need', 'to', 'get', 'to', 'the', 'vet', 'between', '12', 'pm', 'and', '5', 'pm', 'on', 'monday', 'what', 'do', 'i', 'have', 'free']
# not found in user utterance: coatesville, locationkeyphrase ['what', 'will', 'the', 'weather', 'be', 'like', 'sunday', 'in', 'coatesville', 'pa']
# not found in user utterance: coatesville, locationkeyphrase ['is', 'it', 'going', 'to', 'rain', 'on', 'halloween', 'in', 'coatesville', 'pa']
# not found in user utterance: coatesville, locationkeyphrase ['will', 'it', 'be', 'windy', 'out', 'sunday', 'in', 'coatesville', 'pa']
# not found in user utterance: coatesville, locationkeyphrase ['will', 'the', 'weekend', 'have', 'any', 'rain', 'in', 'coatesville', 'pa']
# not found in user utterance: coatesville, locationkeyphrase ['will', 'it', 'rain', 'on', 'saturday', 'in', 'coatesville', 'pa']
# not found in user utterance: goodforgroups placefeature ['i', 'need', 'to', 'know', 'if', 'it', 'can', 'accommodate', 'large', 'groups']
# not found in user utterance: goodforgroups placefeature ['is', 'it', 'good', 'for', 'groups']
# not found in user utterance: outdoordining placefeature ['can', 'we', 'sit', 'outside', 'at', 'that', 'restaurant']
# not found in user utterance: output path ['oops', 'i', 'meant', 'in', 'the', 'fall']
# not found in user utterance: output path ['for', 'real', 'this', 'time', 'i', 'meant', 'summer']
# not found in user utterance: february month ['do', 'i', 'have', 'a', 'holiday', 'party', 'that', 'i', 'need', 'to', 'be', 'at', 'on', 'feb', '14', 'i', 'need', 'to', 'know', 'so', 'that', 'it', "doesn't", 'conflict', 'with', 'the', 'conference']
# not found in user utterance: $100 string ['create', 'an', 'event', 'called', 'groceries', 'budget', '100', 'on', 'tuesday']
# not found in user utterance: edward personname ['what', 'is', "edward's", 'email']
# not found in user utterance: output path ['add', 'central', 'park', 'conference', 'as', 'the', 'location']
# not found in user utterance: output path ['change', 'the', 'name', 'to', 'lunch', 'meeting', 'at', 'dominos']
# not found in user utterance: output path ['not', 'that', 'one', 'the', 'one', 'on', 'the', '14th']
# not found in user utterance: output path ['jakes', 'does', 'not', 'get', 'in', 'until', '9', '30', 'can', 'you', 'start', 'that', 'at', '10', '00', 'instead']
# not found in user utterance: output path ['what', 'about', 'the', 'next', 'month']
# not found in user utterance: output path ['sorry', 'i', 'meant', 'delete', 'the', 'event', 'called', 'bar', 'hopping']
# not found in user utterance: [] list[path] ['what', 'about', 'cairo']
# not found in user utterance: place path ['what', 'about', 'cairo']
# not found in user utterance: output path ['i', 'meant', 'thursday']
# not found in user utterance: declined responsestatustype ['decline', 'homecoming', 'dance']
# not found in user utterance: output path ['make', 'it', 'an', 'hour', 'instead']
# not found in user utterance: accepted responsestatustype ['is', 'ramy', 'is', 'attending', 'the', 'dinner', 'date']
# not found in user utterance: accepted responsestatustype ['who', 'is', 'coming', 'to', 'pilates']
# not found in user utterance: output path ['i', 'meant', 'to', 'say', 'jared']
# not found in user utterance: kim personname ['who', 'is', 'on', "kim's", 'team']
# not found in user utterance: jennifer personname ['what', 'about', "jennifer's", 'team']
# not found in user utterance: tuesday dayofweek ['can', 'you', 'please', 'add', 'sam', 'and', 'violet', 'to', "tuesday's", '3', 'pm', 'meeting']
# not found in user utterance: eric personname ['find', 'the', 'name', 'of', "eric's", 'boss']
# not found in user utterance: eric personname ['set', 'up', 'a', 'meeting', 'with', "eric's", 'manager', 'dan', 'schoffel', 'to', 'go', 'over', 'design', 'plans', 'on', 'friday', 'at', '4', '00', 'pm']
# not found in user utterance: output path ['looks', 'good', 'invite', 'patrick']
# not found in user utterance: output path ['invite', 'eric', 'then']
# not found in user utterance: output path ['its', 'cool', 'and', 'extend', 'the', 'end', 'time', 'til', '5', 'pm']
# not found in user utterance: output path ["let's", 'move', 'this', 'to', 'a', 'room', 'in', 'cambridge', 'and', "let's", 'make', 'it', 'for', 'the', '23rd']
# not found in user utterance: output path ['no', 'make', 'it', 'later', 'in', 'the', 'day', 'please']
# not found in user utterance: [] list[path] ['no', 'make', 'it', 'later', 'in', 'the', 'day', 'please']
# not found in user utterance: start path ['no', 'make', 'it', 'later', 'in', 'the', 'day', 'please']
# not found in user utterance: fullbar placefeature ['can', 'i', 'get', 'an', 'adult', 'drink', 'there']
# not found in user utterance: familyfriendly placefeature ['would', 'you', 'consider', 'paisan', 'family', 'friendly', 'or', 'not']
# not found in user utterance: malik personname ['can', 'you', 'give', 'me', "malik's", 'phone', 'number']
# not found in user utterance: true boolean ['when', 'i', 'am', 'free', 'today']
# not found in user utterance: [] list[path] ['please', 'label', 'the', 'first', 'event', 'as', 'dinner', 'meeting']
# not found in user utterance: [] list[path] ['i', 'prefer', 'the', 'first', 'one']
# not found in user utterance: output path ['can', 'you', 'remove', 'jesse', 'and', 'add', "kim's", 'team']
# not found in user utterance: kim personname ['can', 'you', 'remove', 'jesse', 'and', 'add', "kim's", 'team']
# not found in user utterance: tim personname ['sure', 'the', 'second', 'one', 'is', 'good', 'then', 'i', 'need', 'to', 'meet', "tim's", 'team', 'on', 'tuesday', 'but', "don't", 'invite', 'dan', 'schoffel', 'and', 'invite', 'terry']
# not found in user utterance: output path ['move', 'that', 'to', 'monday']
# not found in user utterance: temperature weatherprop ['how', 'cold', 'is', 'it', 'in', 'pittsburgh', 'pa', 'right', 'now']
# not found in user utterance: summarize weatherquantifier ['how', 'cold', 'is', 'it', 'in', 'pittsburgh', 'pa', 'right', 'now']
# not found in user utterance: pittsburgh, locationkeyphrase ['how', 'cold', 'is', 'it', 'in', 'pittsburgh', 'pa', 'right', 'now']
# not found in user utterance: buffalo, locationkeyphrase ['will', 'it', 'rain', 'in', 'buffalo', 'ny', 'this', 'week']
# not found in user utterance: philadelphia, locationkeyphrase ['any', 'chance', 'of', 'snow', 'for', 'philadelphia', 'pa', 'this', 'week']
# not found in user utterance: bring? respondcomment ['hey', 'accept', 'the', 'bbq', 'meet', 'up', 'for', 'next', 'week', 'with', 'the', 'comment', 'what', 'would', 'you', 'like', 'me', 'to', 'bring']
# not found in user utterance: accepted responsestatustype ['hey', 'accept', 'the', 'bbq', 'meet', 'up', 'for', 'next', 'week', 'with', 'the', 'comment', 'what', 'would', 'you', 'like', 'me', 'to', 'bring']
# not found in user utterance: accepted responsestatustype ['thanks', 'accept', 'my', 'calligraphy', 'lesson', 'and', 'say', 'that', "i'll", 'bring', 'my', 'new', 'pens']
# not found in user utterance: accepted responsestatustype ['thank', 'you', 'and', 'please', 'accept', 'my', 'diving', 'lessons']
# not found in user utterance: output path ['one', 'day', 'after', 'the', 'day', 'is', 'when', 'we', 'will', 'meet']
# not found in user utterance: output path ['actually', 'remove', 'steve', 'and', 'tom', 'and', 'add', 'logan', 'and', 'martha']
# not found in user utterance: output path ['is', 'there', 'anytime', 'earlier']
# not found in user utterance: [] list[path] ['is', 'there', 'anytime', 'earlier']
# not found in user utterance: start path ['is', 'there', 'anytime', 'earlier']
# not found in user utterance: [] list[path] ['make', 'that', 'start', 'earlier', 'than', 'it', 'currently', 'does']
# not found in user utterance: output path ['could', 'you', 'show', 'me', 'the', 'earlier', 'times', 'please']
# not found in user utterance: [] list[path] ['could', 'you', 'show', 'me', 'the', 'earlier', 'times', 'please']
# not found in user utterance: start path ['could', 'you', 'show', 'me', 'the', 'earlier', 'times', 'please']
# not found in user utterance: output path ['add', 'the', 'location', 'as', 'the', 'house', 'of', 'blues', 'dallas']
# not found in user utterance: november month ['could', 'you', 'schedule', 'a', 'birthday', 'party', 'on', 'nov', '5th', 'of', 'that', 'year']
# not found in user utterance: friday dayofweek ['thursday', 'is', 'going', 'to', 'be', 'a', 'late', 'night', "let's", 'update', "friday's", 'netflix', 'and', 'chill', 'sesh', 'to', 'start', 'at', '3', 'pm']
# not found in user utterance: saturday dayofweek ['add', 'coffee', 'with', 'marina', 'from', '8', 'am', 'to', '9', 'am', 'at', 'the', 'starbucks', 'on', 'melrose', 'to', "saturday's", 'calendar']
# not found in user utterance: output path ['it', 'will', 'be', 'at', 'noon']
# not found in user utterance: accepted responsestatustype ['who', 'all', 'is', 'coming', 'to', 'the', '49ers', 'game']
# not found in user utterance: meeting string ['what', 'meetings', 'did', 'i', 'have', 'earlier', 'today']
# not found in user utterance: gonano personname ['put', 'abby', "gonano's", 'team', 'for', 'a', 'meeting']
# not found in user utterance: cobb personname ['the', 'second', 'is', 'fine', 'add', 'drinks', 'with', 'jake', "cobb's", 'team', 'on', 'friday', 'at', '5', 'pm']
# not found in user utterance: cobb personname ['put', 'jake', "cobb's", 'team', 'for', 'a', 'meeting']
# not found in user utterance: wednesday dayofweek ['hey', 'i', 'need', 'to', 'add', 'shop', 'for', 'cat', 'supplies', 'to', 'my', 'scedule', 'this', 'wed', 'at', '4', 'pm']
# not found in user utterance: at&t locationkeyphrase ['can', 'you', 'schedule', 'a', 'football', 'game', 'at', 'the', 'at', 't', 'center', 'for', 'saturday', 'at', '11', '30', 'am']
# not found in user utterance: output path ['no', 'the', 'magic', 'tournament', 'should', 'be', 'this', 'saturday', '10', '12']
# not found in user utterance: outofoffice showasstatus ['schedule', 'an', 'optometrist', 'appointment', 'tomorrow', 'at', '1', '30', 'pm', 'and', 'set', 'my', 'status', 'to', 'out', 'of', 'office']
# not found in user utterance: output path ['yes', 'add', 'james', 'dan', 'davis', 'and', 'jessica', 'to', 'this', 'event']
# not found in user utterance: output path ["let's", 'start', 'at', '4', 'pm']
# not found in user utterance: output path ['no', 'it', 'should', 'be', '72', 'hours', 'long']
# not found in user utterance: output path ['call', 'it', 'pre', 'eat', 'party']
# not found in user utterance: output path ['i', 'need', 'it', 'to', 'last', 'for', 'at', 'least', '2', 'hours']
# not found in user utterance: happyhour placefeature ['are', 'there', 'half', 'priced', 'drinks', 'after', 'a', 'certain', 'time', 'at', 'the', 'wobbly', 'olive']
# not found in user utterance: outdoordining placefeature ['do', 'they', 'have', 'a', 'patio']
# not found in user utterance: familyfriendly placefeature ['would', 'it', 'be', 'alright', 'if', 'i', 'brought', 'small', 'children', 'to', 'this', 'restaurant']
# not found in user utterance: output path ['add', 'the', 'location', 'at', 'the', 'park']
# not found in user utterance: output path ['what', 'about', 'friday']
# not found in user utterance: output path ['are', 'there', 'any', 'next', 'week', 'after', 'that']
# not found in user utterance: workingelsewhere showasstatus ['mark', 'me', 'as', 'working', 'elsewhere', 'for', 'that', 'time', 'so', 'no', 'one', 'looks', 'for', 'me', 'in', 'my', 'office']
# not found in user utterance: november month ['nov', '13th', 'at', '5pm', 'set', 'an', 'alert', 'for', 'shopping']
# not found in user utterance: accepted responsestatustype ['who', 'is', 'coming', 'to', 'dinner', 'on', 'tuesday']
# not found in user utterance: output path ['can', 'you', 'include', 'michael', 'in', 'that']
# not found in user utterance: output path ['make', 'it', 'last', '3', 'hours', 'please']
# not found in user utterance: outofoffice showasstatus ['put', 'my', 'fishing', 'trip', 'with', 'bernie', 'and', 'ryan', 'from', 'august', '1st', 'for', 'five', 'days', "i'll", 'be', 'gone', 'from', 'the', 'office']
# not found in user utterance: accepted responsestatustype ['did', 'anyone', 'not', 'accept', 'late', 'lunch']
# not found in user utterance: output path ['make', 'that', '9', '10', '30']
# not found in user utterance: end path ['make', 'that', '9', '10', '30']
# not found in user utterance: output path ['make', 'it', '45', 'minutes', 'rather', 'than', '30', 'please']
# not found in user utterance: output path ['that', 'will', 'end', 'at', '10', 'am', 'and', 'it', 'is', 'going', 'to', 'be', 'at', "steve's", 'office']
# not found in user utterance: output path ['have', 'this', 'ending', 'at', '6']
# not found in user utterance: output path ['change', 'the', 'time', 'to', '6pm']
# not found in user utterance: fullbar placefeature ['does', 'miller', 'union', 'in', 'atlanta', 'have', 'a', 'full', 'bar']
# not found in user utterance: fullbar placefeature ['does', "bandana's", 'bar', 'b', 'q', 'in', 'evansville', 'have', 'a', 'full', 'bar']
# not found in user utterance: bar-b-q locationkeyphrase ['does', "bandana's", 'bar', 'b', 'q', 'in', 'evansville', 'have', 'a', 'full', 'bar']
# not found in user utterance: fullbar placefeature ['does', "haru's", 'in', 'reno', 'have', 'a', 'bar']
# not found in user utterance: fullbar placefeature ['miller', 'union', 'in', 'atlanta', 'have', 'a', 'bar']
# not found in user utterance: fullbar placefeature ['does', "pj's", 'in', 'reno', 'have', 'a', 'bar']
# not found in user utterance: fullbar placefeature ['does', 'walk', "on's", 'in', 'mobile', 'have', 'a', 'full', 'bar']
# not found in user utterance: walk-on's locationkeyphrase ['does', 'walk', "on's", 'in', 'mobile', 'have', 'a', 'full', 'bar']
# not found in user utterance: movie string ['i', 'need', 'to', 'check', 'to', 'make', 'sure', 'sue', 'got', 'my', 'invite']
# not found in user utterance: night string ['i', 'need', 'to', 'check', 'to', 'make', 'sure', 'sue', 'got', 'my', 'invite']
# not found in user utterance: accepted responsestatustype ['has', 'david', 'lax', 'responded', 'to', 'the', 'lunch', 'meeting']
# not found in user utterance: accepted responsestatustype ['did', 'sue', 'accept', 'movie', 'night']
# not found in user utterance: output path ['it', 'will', 'only', 'last', 'until', '11', '35', 'pm']
# not found in user utterance: output path ['make', 'me', 'meeting', 'not', 'this', 'weekend']
# not found in user utterance: output path ['not', 'on', 'the', 'weekend', 'please']
# not found in user utterance: output path ['actually', 'i', "don't", 'want', 'it', 'on', 'the', 'weekend']
# not found in user utterance: output path ['no', "that's", 'not', 'what', 'i', 'want', 'rename', 'that', 'appointment', 'meeting', 'with', 'divorce', 'lawyers', 'and', 'make', 'it', 'for', '10', '30am']
# not found in user utterance: output path ['no', 'it', 'needs', 'to', 'be', 'at', 'least', 'an', 'hour']
# not found in user utterance: [] list[path] ['show', 'me', 'the', 'second', 'one', 'please']
# not found in user utterance: appointment string ['do', 'i', 'have', 'any', 'dermatologist', 'appointments', 'this', 'month']
# not found in user utterance: dan personname ['can', 'you', 'show', 'me', "dan's", 'number']
# not found in user utterance: temperature weatherprop ['when', 'will', 'it', 'be', 'warmest', 'this', 'weekend']
# not found in user utterance: max weatherquantifier ['when', 'will', 'it', 'be', 'warmest', 'this', 'weekend']
# not found in user utterance: accepted responsestatustype ['okay', 'willing', 'to', 'accept', 'that', 'proposition']
# not found in user utterance: jeanie's string ['schedule', 'john', 'and', "jennie's", 'anniversary', 'party', 'on', 'sunday', 'at', '3', '00', 'to', '4', '00', 'pm']
# not found in user utterance: output path ['yes', 'ok', 'can', 'you', 'add', 'cameron', 'to', 'the', 'list', 'of', 'attendees', 'as', 'well']
# not found in user utterance: output path ['good', 'delete', 'angie', 'though']
# not found in user utterance: output path ['make', 'that', '1', 'hour', 'after', 'now']
# not found in user utterance: independenceday holiday ['schedule', 'a', 'vacation', 'day', 'on', 'independence', 'day', 'next', 'year']
# not found in user utterance: output path ['make', 'it', 'til', '7']
# not found in user utterance: tuesday dayofweek ['set', 'lunch', 'date', 'with', 'sue', 'at', 'noon', 'on', 'tuesda']
# not found in user utterance: output path ['make', 'the', 'starting', 'time', 'at', '3', 'pm']
# not found in user utterance: diego, locationkeyphrase ['do', 'you', 'know', 'what', 'the', 'weather', 'will', 'be', 'tomorrow', 'in', 'san', 'diego', 'california']
# not found in user utterance: cincinnati, locationkeyphrase ['what', 'about', 'the', 'weather', 'tomorrow', 'in', 'cincinnati', 'oh']
# not found in user utterance: diego, locationkeyphrase ['i', 'understand', 'can', 'i', 'wear', 'flip', 'flops', 'tomorrow', 'in', 'san', 'diego', 'california']
# not found in user utterance: output path ['actually', 'change', 'the', 'time', 'to', '4pm']
# not found in user utterance: november month ['what', 'will', 'the', 'weather', 'be', 'like', 'in', 'nashville', 'on', 'nov', '4th']
# not found in user utterance: january month ['create', 'an', 'event', 'called', 'ice', 'fishing', 'trip', 'for', 'jan', '11', 'until', 'jan', '14']
# not found in user utterance: january month ['create', 'an', 'event', 'called', 'ice', 'fishing', 'trip', 'for', 'jan', '11', 'until', 'jan', '14']
# not found in user utterance: waiterservice placefeature ['does', 'm3', 'in', 'reno', 'have', 'waiter', 'service']
# not found in user utterance: waiterservice placefeature ['how', 'about', 'round', 'about', 'grill', 'in', 'reno', 'does', 'it', 'have', 'waiter', 'service']
# not found in user utterance: waiterservice placefeature ['okay', 'i', 'will', 'email', 'them', 'tonight', 'does', "katie's", 'in', 'new', 'orleans', 'have', 'waiter', 'service', 'thanks']
# not found in user utterance: output path ['actually', 'could', 'you', 'make', 'that', 'change', 'to', 'the', 'bbq']
# not found in user utterance: output path ['actually', 'i', 'meant', 'lunch', 'break', 'on', 'sunday']
# not found in user utterance: output path ['i', 'meant', 'the', 'peanut', 'pick', 'on', 'the', '13th']
# not found in user utterance: output path ['it', 'was', 'at', 'noon']
# not found in user utterance: output path ['at', 'panera', 'add']
# not found in user utterance: output path ['do', 'any', 'happen', 'after', '8pm', 'i', 'work', 'later', 'that', 'day']
# not found in user utterance: [] list[path] ['i', 'need', 'the', 'budget', 'meeting', 'tomorrow', 'to', 'be', 'later', 'in', 'the', 'day']
# not found in user utterance: start path ['i', 'need', 'the', 'budget', 'meeting', 'tomorrow', 'to', 'be', 'later', 'in', 'the', 'day']
# not found in user utterance: accepted responsestatustype ['accept', 'my', 'pizza', 'party']
# not found in user utterance: declined responsestatustype ['decline', 'that', 'and', 'send', 'a', 'response', 'to', 'all', 'that', 'it', 'has', 'been', 'cancelled']
# not found in user utterance: accepted responsestatustype ['wait', "that's", 'not', 'mine', 'accept', 'it', 'again', 'and', 'say', "i'm", 'looking', 'forward', 'to', 'it']
# not found in user utterance: it. respondcomment ['wait', "that's", 'not', 'mine', 'accept', 'it', 'again', 'and', 'say', "i'm", 'looking', 'forward', 'to', 'it']
# not found in user utterance: [] list[path] ['make', 'it', 'a', 'little', 'later', 'in', 'the', 'day']
# not found in user utterance: start path ['make', 'it', 'a', 'little', 'later', 'in', 'the', 'day']
# not found in user utterance: output path ['can', 'we', 'make', 'the', 'appointment', 'a', 'half', 'hour', 'later']
# not found in user utterance: [] list[path] ['can', 'we', 'make', 'the', 'appointment', 'a', 'half', 'hour', 'later']
# not found in user utterance: start path ['can', 'we', 'make', 'the', 'appointment', 'a', 'half', 'hour', 'later']
# not found in user utterance: output path ['i', 'need', 'this', 'appointment', 'to', 'be', 'later', 'in', 'the', 'day']
# not found in user utterance: [] list[path] ['i', 'need', 'this', 'appointment', 'to', 'be', 'later', 'in', 'the', 'day']
# not found in user utterance: start path ['i', 'need', 'this', 'appointment', 'to', 'be', 'later', 'in', 'the', 'day']
# not found in user utterance: output path ['change', 'the', 'time', 'to', 'noon']
# not found in user utterance: output path ['good', 'and', 'also', 'invite', 'mike', 'molly', 'and', 'todd']
# not found in user utterance: output path ['10', 'pm', 'also', 'monday', 'also', 'get', 'alex', 'trebek', 'on', 'there']
# not found in user utterance: output path ['have', 'it', 'end', 'at', '3', '45', 'pm']
# not found in user utterance: output path ['put', 'starbucks', 'as', 'the', 'location', 'for', 'that', 'coffee']
# not found in user utterance: output path ['yes', 'extend', 'til', '7']
# not found in user utterance: output path ["i'd", 'like', 'it', 'to', 'start', 'at', '7', 'am', 'actually']
# not found in user utterance: [] list[path] ['fayetteville', 'nc']
# not found in user utterance: place path ['fayetteville', 'nc']
# not found in user utterance: output path ['i', 'meant', 'the', 'one', 'next', 'monday']
# not found in user utterance: danna personname ['who', 'is', "danna's", 'manager']
# not found in user utterance: ron personname ['who', 'is', "ron's", 'boss']
# not found in user utterance: ron personname ['put', 'on', 'calendar', 'to', 'meet', 'with', "ron's", 'manager', 'dan', 'schoffel', 'to', 'talk', 'about', 'partnership', 'options', 'on', 'monday', 'at', '3', '00', 'pm']
# not found in user utterance: output path ["it's", 'good', 'momo', 'and', 'appa', 'need', 'to', 'be', 'invited']
# not found in user utterance: accepted responsestatustype ['who', 'is', 'coming', 'to', 'the', 'golfing']
# not found in user utterance: fullbar placefeature ['does', 'the', 'hibachi', 'by', 'burleson', 'have', 'a', 'full', 'bar', 'make', 'sure', 'they', 'have', 'patron', 'tequila']
# not found in user utterance: fullbar placefeature ['does', 'taco', 'mama', 'in', 'mountain', 'brk', 'have', 'a', 'full', 'bar']
# not found in user utterance: fullbar placefeature ['does', 'sanctuary', 'in', 'iowa', 'city', 'have', 'a', 'full', 'bar']
# not found in user utterance: waiterservice placefeature ['13', 'coins', 'in', 'bellvue', 'has', 'waiter', 'service', 'yes', 'or', 'no']
# not found in user utterance: waiterservice placefeature ['does', 'arbys', 'have', 'waiter', 'service']
# not found in user utterance: waiterservice placefeature ['does', 'monsoon', 'in', 'bellvue', 'have', 'waiter', 'service']
# not found in user utterance: dr. locationkeyphrase ['thanks', 'schedule', 'a', 'dentist', 'appointment', 'at', 'dr', "arnold's", 'next', 'friday']
# not found in user utterance: eugene, locationkeyphrase ['i', 'need', 'to', 'know', 'that', 'the', 'weather', 'will', 'be', 'in', 'eugene', 'oregon']
# not found in user utterance: temperature weatherprop ['what', 'will', 'it', 'be', 'in', '35', 'minutes']
# not found in user utterance: summarize weatherquantifier ['what', 'will', 'it', 'be', 'in', '35', 'minutes']
# not found in user utterance: output path ["it's", 'at', "gold's", 'gym']
# not found in user utterance: output path ['actually', 'move', 'it', 'two', 'hours', 'back']
# not found in user utterance: friday dayofweek ['add', 'coffee', 'with', 'elaine', 'at', '8', 'a', 'm', 'to', "friday's", 'schedule']
# not found in user utterance: output path ['change', 'the', 'time', 'at', '9', 'am']
# not found in user utterance: output path ['invite', 'jon', 'darren', 'and', 'jack', 'to', 'it']
# not found in user utterance: jimmy, string ['please', 'add', 'a', 'reminder', 'on', 'saturday', 'at', '9am', 'to', 'pickup', 'jimmy', 'billy', 'and', 'stephen', 'on', 'the', 'way', 'to', "jonny's", 'basketball', 'game']
# not found in user utterance: billy, string ['please', 'add', 'a', 'reminder', 'on', 'saturday', 'at', '9am', 'to', 'pickup', 'jimmy', 'billy', 'and', 'stephen', 'on', 'the', 'way', 'to', "jonny's", 'basketball', 'game']
# not found in user utterance: output path ['no', 'i', 'actually', 'want', 'to', 'bring', 'jen', 'steven', 'and', 'bill']
# not found in user utterance: accepted responsestatustype ['did', 'i', 'accept', 'the', 'sales', 'meeting', 'tomorrow']
# not found in user utterance: accepted responsestatustype ['has', 'sara', 'responded', 'to', 'the', 'budget', 'meeting', 'on', 'friday']
# not found in user utterance: output path ["let's", 'take', 'bill', 'with', 'me']
# not found in user utterance: output path ['actually', 'bill', 'will', 'be', 'on', 'a', 'business', 'trip', 'so', 'he', "can't", 'come']
# not found in user utterance: output path ['please', 'remove', 'bill', 'from', 'that', 'event']
# not found in user utterance: tentativelyaccepted responsestatustype ['who', 'is', 'maybe', 'coming', 'to', 'the', 'zippo', 'convention']
# not found in user utterance: tentativelyaccepted responsestatustype ['hey', 'for', 'game', 'day', 'who', 'is', 'maybe', 'coming']
# not found in user utterance: tentativelyaccepted responsestatustype ['is', 'anyone', 'maybe', 'attending', 'my', 'ping', 'pong', 'tournament']
# not found in user utterance: summarize weatherquantifier ["what's", 'the', 'temperature', 'like', 'tomorrow']
# not found in user utterance: summarize weatherquantifier ["what's", 'the', 'temperature', 'right', 'now']
# not found in user utterance: summarize weatherquantifier ["what's", 'the', 'temperature', 'in', 'casper', 'wyoming']
# not found in user utterance: casper, locationkeyphrase ["what's", 'the', 'temperature', 'in', 'casper', 'wyoming']
# not found in user utterance: output path ['john', 'declined', 'the', 'invitation', 'he', 'is', 'replaced', 'by', 'steve']
# not found in user utterance: december month ['awesome', 'thanks', 'well', 'then', 'could', 'you', 'tell', 'if', 'i', 'have', 'anything', 'going', 'on', 'in', 'dec', '2021']
# not found in user utterance: output path ['it', 'should', 'be', 'an', 'hour', 'long']
# not found in user utterance: independenceday holiday ['when', 'is', 'independence', 'day']
# not found in user utterance: meeting string ['what', 'dinner', 'meetings', 'do', 'i', 'have', 'set', 'up', 'for', 'may', '2020']
# not found in user utterance: temperature weatherprop ['how', 'cold', 'is', 'it', 'going', 'to', 'be', 'then']
# not found in user utterance: summarize weatherquantifier ['how', 'cold', 'is', 'it', 'going', 'to', 'be', 'then']
# not found in user utterance: declined responsestatustype ['who', 'is', 'not', 'going', 'to', 'the', 'baseball', 'game']
# not found in user utterance: output path ['create', 'it', 'for', 'tuesday', 'april', '16']
# not found in user utterance: output path ['yes', 'please', 'add', 'chelsea', 'don', 'and', 'harold']
# not found in user utterance: output path ['add', 'this', 'at', 'walmart']
# not found in user utterance: output path ['okay', "we're", 'going', 'at', '10', 'though']
# not found in user utterance: output path ['no', 'we', 'decided', 'to', 'go', 'at', 'noon']
# not found in user utterance: output path ['make', 'it', '4', 'hours', 'long']
# not found in user utterance: output path ['extend', 'the', 'time', 'so', 'that', 'it', 'will', 'end', 'at', '12', '30', 'pm']
# not found in user utterance: output path ['yes', 'thank', 'you', 'very', 'much', 'and', 'add', 'john', 'to', 'the', 'dinner']
# not found in user utterance: output path ['lines', 'are', 'huge', "let's", 'actually', 'go', 'see', 'it', 'in', 'spring']
# not found in user utterance: memorialday holiday ['will', 'i', 'be', 'meeting', 'with', 'kayla', 'on', 'memorial', 'day']
# not found in user utterance: rachelle personname ['can', 'you', 'book', 'lunch', 'with', "rachelle's", 'boss', 'after', 'my', 'appointment']
# not found in user utterance: veteransday holiday ['do', 'i', 'have', 'anything', 'scheduled', 'on', "veteran's", 'day', 'this', 'year']
# not found in user utterance: memorialday holiday ['tell', 'me', 'when', 'memorial', 'day', 'is']
# not found in user utterance: memorialday holiday ['when', 'was', 'memorial', 'day', 'two', 'years', 'ago']
# not found in user utterance: newyearseve holiday ['what', 'day', 'of', 'the', 'week', 'is', 'new', 'years', 'eve', 'on']
# not found in user utterance: fathersday holiday ['what', 'day', 'of', 'the', 'week', 'is', "father's", 'day', 'on']
# not found in user utterance: none responsestatustype ['who', 'has', 'yet', 'to', 'reply', 'about', 'the', 'meeting', 'tomorrow', 'afternoon']
# not found in user utterance: none responsestatustype ['and', 'who', 'are', 'we', 'waiting', 'on', 'for', 'a', 'response', 'for', 'my', 'friday', 'afternoon', 'meeting']
# not found in user utterance: none responsestatustype ['oh', 'sorry', 'i', 'meant', 'who', "hasn't", 'responded', 'to', 'the', 'thursday', 'afternoon', 'meeting']
# not found in user utterance: sunday dayofweek ['need', 'to', 'set', 'an', 'event', 'on', 'sundays', 'at', '1000']
# not found in user utterance: output path ['make', 'it', 'go', 'to', '11', '3']
# not found in user utterance: output path ['no', 'have', 'it', 'start', 'at', '11', '3']
# not found in user utterance: output path ['something', 'later', 'than', 'than', 'please']
# not found in user utterance: [] list[path] ['something', 'later', 'than', 'than', 'please']
# not found in user utterance: start path ['something', 'later', 'than', 'than', 'please']
# not found in user utterance: output path ['can', 'you', 'make', 'this', 'a', 'little', 'bit', 'later', 'please']
# not found in user utterance: [] list[path] ['can', 'you', 'make', 'this', 'a', 'little', 'bit', 'later', 'please']
# not found in user utterance: start path ['can', 'you', 'make', 'this', 'a', 'little', 'bit', 'later', 'please']
# not found in user utterance: output path ['i', 'need', 'it', 'to', 'be', 'later', 'in', 'the', 'evening']
# not found in user utterance: output path ['can', 'we', 'go', 'with', 'a', 'later', '7', '10', 'start', 'time']
# not found in user utterance: output path ['actually', 'update', 'it', 'to', '3', 'hours']
# not found in user utterance: output path ['actually', 'i', 'want', 'that', 'in', 'the', 'spring']
# not found in user utterance: memorialday holiday ['when', 'is', 'memorial', 'day']
# not found in user utterance: memorialday holiday ['when', 'does', 'memorial', 'day', 'fall', 'on', 'in', '2022']
# not found in user utterance: output path ['i', 'meant', 'the', 'one', 'on', 'friday']
# not found in user utterance: output path ['i', 'meant', 'the', 'one', 'on', 'thursday']
# not found in user utterance: output path ['actually', 'i', 'did', 'mean', 'the', 'one', 'of', 'the', '28th']
# not found in user utterance: output path ['what', 'about', 'the', 'following', 'day']
# not found in user utterance: output path ['1300', 'looks', 'great', 'just', 'make', 'it', 'an', 'hour', 'and', 'a', 'half', 'long', 'meeting', "that's", 'out', 'of', 'the', 'office']
# not found in user utterance: outofoffice showasstatus ['1300', 'looks', 'great', 'just', 'make', 'it', 'an', 'hour', 'and', 'a', 'half', 'long', 'meeting', "that's", 'out', 'of', 'the', 'office']
# not found in user utterance: declined responsestatustype ['maggie', 'and', 'i', "aren't", 'going', 'to', 'the', 'movie', 'on', 'friday', 'anymore']
# not found in user utterance: declined responsestatustype ['no', 'i', 'meant', 'we', "aren't", 'going', 'to', 'dinner', 'on', 'friday', 'now']
# not found in user utterance: output path ['change', 'the', 'ending', 'time', 'to', '1', '15', 'pm']
# not found in user utterance: d&d string ['who', 'has', 'not', 'accepted', 'the', 'd', 'd', 'night', 'for', 'saturday']
# not found in user utterance: tentativelyaccepted responsestatustype ['who', 'has', 'not', 'tentatively', 'accepted', 'my', 'med', 'bay', 'brawl']
# not found in user utterance: output path ['the', 'sandwich', 'actually', 'happened', 'at', '2', 'can', 'you', 'update', 'that']
# not found in user utterance: output path ['yes', 'but', 'change', 'the', 'title', 'to', 'pedicure', 'appointment']
# not found in user utterance: output path ['add', 'the', 'location', 'florida', 'mall']
# not found in user utterance: true boolean ['cancel', 'my', 'one', 'on', 'one', 'with', 'my', 'manager']
# not found in user utterance: jana personname ['can', 'you', 'please', 'find', 'the', 'date', 'for', 'my', 'upcoming', 'meeting', 'with', "jana's", 'supervisor']
# not found in user utterance: true boolean ['she', 'canceled', 'on', 'me', 'delete', 'the', 'all', 'day', 'event', 'with', 'kim']
# not found in user utterance: output path ['sure', 'just', 'make', 'it', 'an', 'hour', 'or', 'so', 'long', 'instead']
# not found in user utterance: output path ['how', 'about', 'the', 'week', 'after', 'next']
# not found in user utterance: accepted responsestatustype ['please', 'accept', 'my', 'invitation', 'to', 'the', 'disneyland', 'afterparty']
# not found in user utterance: accepted responsestatustype ['perfect', 'can', 'you', 'also', 'accept', 'my', 'chess', 'tournament', 'with', 'kim']
# not found in user utterance: declined responsestatustype ['yes', 'lastly', 'can', 'you', 'please', 'decline', 'my', 'laser', 'tag', 'event', 'with', 'dan']
# not found in user utterance: output path ['what', 'about', 'the', 'rest', 'of', 'the', 'month']
# not found in user utterance: output path ['how', 'about', 'at', '11', 'pm']
# not found in user utterance: [] list[path] ['anything', 'tomorrow', 'at', 'that', 'time']
# not found in user utterance: start path ['anything', 'tomorrow', 'at', 'that', 'time']
# not found in user utterance: output path ['what', 'about', 'sunday']
# not found in user utterance: declined responsestatustype ['please', 'decline', 'the', 'review', 'meeting', 'request', 'from', 'sue']
# not found in user utterance: schoffel personname ['ok', 'when', 'do', 'i', 'meet', 'next', 'with', 'someone', 'on', 'dan', "schoffel's", 'team']
# not found in user utterance: kim personname ['yes', 'and', 'do', 'i', 'have', 'anything', 'with', 'any', 'of', "kim's", 'reports', 'today']
# not found in user utterance: washington, string ['next', 'monday', 'to', 'thursday', 'schedule', 'trip', 'to', 'washington', 'dc']
# not found in user utterance: output path ['make', 'the', 'location', "applebee's", 'in', 'cleveland']
# not found in user utterance: output path ['change', 'the', 'dinner', 'time', 'at', '5', '30', 'pm', '6', '00', 'pm']
# not found in user utterance: beach, locationkeyphrase ['can', 'you', 'tell', 'me', 'what', 'the', 'weather', 'will', 'be', 'like', 'in', 'april', 'in', 'panama', 'city', 'beach', 'florida']
# not found in user utterance: beach, locationkeyphrase ['can', 'you', 'tell', 'me', 'what', 'the', 'typical', 'weather', 'will', 'be', 'like', 'in', 'april', 'in', 'panama', 'city', 'beach', 'florida']
# not found in user utterance: beach, locationkeyphrase ['ok', 'how', 'is', 'the', 'weather', 'in', 'daytona', 'beach', 'florida']
# not found in user utterance: beach, locationkeyphrase ['is', 'it', 'going', 'to', 'rain', 'today', 'in', 'panama', 'city', 'beach', 'florida']
# not found in user utterance: beach, locationkeyphrase ['is', 'it', 'going', 'to', 'rain', 'in', 'daytona', 'beach', 'florida']
# not found in user utterance: temperature weatherprop ['is', 'there', 'anywhere', 'in', 'florida', 'warmer', 'than', '70', 'degrees', 'today']
# not found in user utterance: max weatherquantifier ['is', 'there', 'anywhere', 'in', 'florida', 'warmer', 'than', '70', 'degrees', 'today']
# not found in user utterance: bay, locationkeyphrase ['what', 'is', 'the', 'weather', 'like', 'in', 'green', 'bay', 'wisconsin']
# not found in user utterance: plano, locationkeyphrase ['what', 'is', 'the', 'weather', 'like', 'in', 'plano', 'texas']
# not found in user utterance: temperature weatherprop ['how', 'cold', 'will', 'it', 'get', 'tonight', 'in', 'green', 'bay', 'wisconsin']
# not found in user utterance: min weatherquantifier ['how', 'cold', 'will', 'it', 'get', 'tonight', 'in', 'green', 'bay', 'wisconsin']
# not found in user utterance: bay, locationkeyphrase ['how', 'cold', 'will', 'it', 'get', 'tonight', 'in', 'green', 'bay', 'wisconsin']
# not found in user utterance: output path ['it', 'should', 'start', 'at', 'noon']
# not found in user utterance: output path ['add', 'my', 'manager', 'to', 'it', 'please']
# not found in user utterance: [] list[path] ['actually', 'can', 'you', 'do', 'earlier']
# not found in user utterance: start path ['actually', 'can', 'you', 'do', 'earlier']
# not found in user utterance: output path ['change', 'time', 'to', 'next', 'week']
# not found in user utterance: accepted responsestatustype ['alright', 'yeah', 'accept', 'it', 'for', 'me']
# not found in user utterance: november month ['wine', 'fest', 'is', 'nov', '8', '12']
# not found in user utterance: output path ['needs', 'to', 'be', 'for', 'a', 'week', 'actually']
# not found in user utterance: [] list[path] ['needs', 'to', 'be', 'for', 'a', 'week', 'actually']
# not found in user utterance: start path ['needs', 'to', 'be', 'for', 'a', 'week', 'actually']
# not found in user utterance: [] list[path] ['what', 'about', 'sunday']
# not found in user utterance: time path ['what', 'about', 'sunday']
# not found in user utterance: output path ['can', 'you', 'make', 'it', 'from', '3', 'to', '11', 'please']
# not found in user utterance: output path ['actually', 'i', 'think', '11', 'is', 'too', 'late', 'make', 'it', '2', 'til', '10', 'instead']
# not found in user utterance: output path ['change', 'the', 'end', 'time', 'to', '2', '00', 'pm']
# not found in user utterance: accepted responsestatustype ['is', 'jim', 'coming', 'on', 'monday']
# not found in user utterance: output path ['add', 'attendees', 'cher', 'roydon', 'and', 'damon', 'ellery']
# not found in user utterance: output path ['duration', 'will', 'be', '1', 'hour']
# not found in user utterance: output path ['yes', 'change', 'title', 'to', 'important', 'meeting']
# not found in user utterance: declined responsestatustype ['please', 'decline', 'lunch', 'with', 'friends', 'tomorrow', 'because', 'i', 'have', 'to', 'leave', 'the', 'office', 'early']
# not found in user utterance: declined responsestatustype ['ok', 'also', 'decline', 'the', 'charity', 'event', 'on', 'saturday', 'telling', 'him', 'i', 'have', 'to', 'babysit']
# not found in user utterance: declined responsestatustype ["i'm", 'going', 'to', 'need', 'to', 'decline', 'the', 'invite', 'to', 'the', 'annual', 'retreat', 'tell', 'them', "i'm", 'not', 'available']
# not found in user utterance: none responsestatustype ['please', 'find', 'all', 'the', 'people', 'who', 'have', 'not', 'responded', 'to', 'my', 'annual', 'bash', 'event', 'request']
# not found in user utterance: none responsestatustype ['who', "hasn't", 'responded', 'to', 'my', 'birthday', 'party', 'invitations', 'yet']
# not found in user utterance: none responsestatustype ['which', 'people', 'did', 'not', 'respond', 'to', 'the', 'camping', 'invite']
# not found in user utterance: none responsestatustype ['who', 'has', 'not', 'respond', 'to', 'the', 'house', 'party', 'on', 'march', '27']
# not found in user utterance: none responsestatustype ['who', "hasn't", 'responded', 'to', 'the', 'back', 'to', 'back', 'dance', 'off']
# not found in user utterance: none responsestatustype ['which', 'people', 'have', 'not', 'responded', 'to', 'the', 'movie', 'invite']
# not found in user utterance: dr. personname ['look', 'up', 'my', 'scheduled', 'appointment', 'with', 'dr', 'sadler']
# not found in user utterance: output path ['sorry', 'no', 'it', 'needs', 'to', 'go', 'from', '3', 'to', '6', 'pm']
# not found in user utterance: output path ['make', 'the', 'end', 'time', '6pm']
# not found in user utterance: output path ['thanks', 'form', '3', '30']
# not found in user utterance: [] list[path] ['elk', 'grove']
# not found in user utterance: place path ['elk', 'grove']
# not found in user utterance: output path ['whoops', 'i', 'meant', 'am']
# not found in user utterance: [] list[path] ['whoops', 'i', 'meant', 'am']
# not found in user utterance: start path ['whoops', 'i', 'meant', 'am']
# not found in user utterance: output path ['whoops', 'can', 'you', 'start', 'that', 'in', 'the', 'pm']
# not found in user utterance: [] list[path] ['whoops', 'can', 'you', 'start', 'that', 'in', 'the', 'pm']
# not found in user utterance: output path ['oh', 'no', 'i', 'meant', 'for', 'you', 'to', 'make', 'it', 'pm']
# not found in user utterance: [] list[path] ['oh', 'no', 'i', 'meant', 'for', 'you', 'to', 'make', 'it', 'pm']
# not found in user utterance: start path ['oh', 'no', 'i', 'meant', 'for', 'you', 'to', 'make', 'it', 'pm']
# not found in user utterance: declined responsestatustype ['decline', 'my', 'next', "tuesday's", 'brainstorming', 'session']
# not found in user utterance: sandy personname ['invite', "sandy's", 'manager', 'to', 'the', 'dinner', 'party']
# not found in user utterance: output path ['fix', 'the', 'time', 'at', '8', 'pm']
# not found in user utterance: [] list[recipient] ['forward', 'it', 'to', 'her']
# not found in user utterance: output path ['make', 'the', 'yoga', 'trip', 'last', 'all', 'day', 'from', 'monday', 'until', 'tuesday', 'if', 'you', 'will']
# not found in user utterance: output path ['i', 'need', 'it', 'for', '3pm']
# not found in user utterance: output path ['change', 'the', 'final', 'day', 'to', 'the', '26th']
# not found in user utterance: [] list[path] ['change', 'the', 'final', 'day', 'to', 'the', '26th']
# not found in user utterance: start path ['change', 'the', 'final', 'day', 'to', 'the', '26th']
# not found in user utterance: output path ['i', 'want', 'the', 'start', 'date', 'to', 'be', 'a', 'day', 'earlier']
# not found in user utterance: [] list[path] ['i', 'want', 'the', 'start', 'date', 'to', 'be', 'a', 'day', 'earlier']
# not found in user utterance: output path ['no', 'make', 'it', 'start', 'on', 'the', '19th']
# not found in user utterance: trap! string ['change', 'a', 'trap', 'to', 'be', 'from', '14', '00', 'to', '15', '00']
# not found in user utterance: outofoffice showasstatus ['can', 'you', 'schedule', 'a', 'basketball', 'practice', 'from', '4', '30', 'to', '6', '30', 'pm', 'tonight', 'and', 'set', 'the', 'showas', 'status', 'as', 'out', 'of', 'office']
# not found in user utterance: [] list[path] ['i', 'am', 'located', 'in', 'san', 'francisco']
# not found in user utterance: place path ['i', 'am', 'located', 'in', 'san', 'francisco']
# not found in user utterance: mr. string ['please', 'search', 'for', 'mr', 'smith', 'and', 'tell', 'when', 'is', 'the', 'meeting', 'with', 'him']
# not found in user utterance: october month ['schedule', 'a', 'all', 'day', 'basketball', 'tournament', 'on', 'oct', '20']
# not found in user utterance: output path ['change', 'the', 'kids', 'outing', 'time', 'at', '3', '00', 'pm', '3', '30', 'pm']
# not found in user utterance: accepted responsestatustype ['please', 'accept', 'my', 'meeting', 'with', 'john', 'for', '4', '00', 'tomorrow']
# not found in user utterance: accepted responsestatustype ['yes', 'thanks', 'then', 'could', 'you', 'accept', 'the', 'bbq', 'meet', 'up', 'for', 'next', 'week', 'for', 'me']
# not found in user utterance: accepted responsestatustype ['perfect', 'can', 'you', 'also', 'accept', 'my', 'laser', 'tag', 'with', 'dan', 'schoffel', 'and', 'tell', 'him', 'ill', 'meet', 'him', 'there']
# not found in user utterance: output path ['make', 'it', 'at', '3', 'pm']
# not found in user utterance: output path ['what', 'about', 'the', 'week', 'after', 'this']
# not found in user utterance: november month ['now', 'change', 'the', 'appointment', 'date', 'from', '9th', 'to', '10th', 'nov']
# not found in user utterance: output path ['change', 'the', 'title', 'of', 'this', 'event', 'to', 'chocolate', 'visit']
# not found in user utterance: output path ['yes', 'add', 'that', 'we', 'were', 'at', 'the', 'city', 'diner']
# not found in user utterance: output path ['yes', 'but', 'change', 'the', 'start', 'time', 'as', '5', 'am']
# not found in user utterance: output path ['that', 'looks', 'good', 'brian', 'and', 'james', 'were', 'there', 'too']
# not found in user utterance: output path ['it', 'should', 'be', '2', 'hours', 'long', 'and', 'should', 'include', 'alex', 'jason', 'and', 'jeff']
# not found in user utterance: jeong-ho personname ['create', 'a', 'lunch', 'with', 'jeong', 'ho', 'kim', 'in', 'two', 'days']
# not found in user utterance: output path ['that', 'will', 'be', 'in', 'the', 'fall']
# not found in user utterance: output path ['and', 'the', 'wine', 'festival']
# not found in user utterance: output path ['and', 'the', 'budget', 'planning', 'meeting']
# not found in user utterance: output path ['what', 'about', 'the', 'sprint', 'call']
# not found in user utterance: output path ['can', 'you', 'add', 'john', 'and', 'his', 'supervisor', 'to', 'this', 'as', 'well']
# not found in user utterance: output path ['make', 'it', 'for', '3', 'hours', 'long']
# not found in user utterance: uvindex weatherprop ['do', 'you', 'do', 'the', 'uv', 'forecast']
# ...
# not found in user utterance: false boolean ['is', 'steve', 'busy', 'tomorrow', 'afternoon']
# not found in user utterance: false boolean ['yes', 'looks', 'good', 'is', 'crim', 'free', 'tomorrow']
# not found in user utterance: false boolean ['is', 'abby', 'free', 'today']
# not found in user utterance: [] list[path] ["i'm", 'in', 'in', 'springfield', 'missouri']
# not found in user utterance: place path ["i'm", 'in', 'in', 'springfield', 'missouri']
# not found in user utterance: september month ['change', 'my', 'travel', 'to', 'lexington', 'on', 'sept', '19', 'to', '1pm']
# not found in user utterance: friday dayofweek ['move', 'fridays', 'dentist', 'appointment', 'to', '3pm']
# not found in user utterance: output path ['can', 'you', 'change', 'the', 'time', 'to', '6']
# not found in user utterance: output path ['can', 'you', 'make', 'homemade', 'pizza', 'party', 'last', '1', '5', 'hours']
# not found in user utterance: columbusday holiday ['when', 'is', 'columbus', 'day']
# not found in user utterance: output path ['change', 'start', 'time', 'as', '2', 'pm', 'and', 'add', "abby's", 'team', 'to', 'it']
# not found in user utterance: abby personname ['change', 'start', 'time', 'as', '2', 'pm', 'and', 'add', "abby's", 'team', 'to', 'it']
# not found in user utterance: output path ['4', 'days', 'after', 'that', 'day']
# not found in user utterance: output path ['another', '4', 'days']
# not found in user utterance: possible personname ['great', 'i', 'want', 'a', 'meeting', 'with', 'kim', "possible's", 'team', 'can', 'you', 'schedule', 'that', 'for', 'me', 'please']
# not found in user utterance: output path ['change', 'the', 'block', 'to', '1', 'hour']
# not found in user utterance: happyhour placefeature ['is', 'there', 'a', 'happy', 'hour', 'at', 'chapel', 'tavern', 'in', 'reno']
# not found in user utterance: happyhour placefeature ['does', 'the', 'twisted', 'fork', 'in', 'reno', 'have', 'a', 'happy', 'hour']
# not found in user utterance: happyhour placefeature ['does', 'oceano', 'offer', 'any', 'deals', 'during', 'happy', 'hour']
# not found in user utterance: [] list[path] ['cancel', 'the', 'first', 'one']
# not found in user utterance: bob personname ['what', 'is', "bob's", 'e', 'mail', 'address']
# not found in user utterance: output path ['actually', 'make', 'it', 'from', '3', '30', 'pm', 'to', 'the', 'end', 'of', 'the', 'work', 'day']
# not found in user utterance: output path ['make', 'it', 'go', 'until', '8']
# not found in user utterance: output path ['it', 'should', 'be', 'an', 'hour', 'long', 'actually']
# not found in user utterance: output path ['never', 'mind', 'change', 'that', 'to', 'march', '21', '10', '30', 'am', 'to', '12', '30', 'pm', 'please']
# not found in user utterance: waiterservice placefeature ['does', 'big', 'fish', 'sushi', 'in', 'bothell', 'have', 'waiters']
# not found in user utterance: waiterservice placefeature ['does', "alexa's", 'cafe', 'in', 'bothell', 'have', 'waiters']
# not found in user utterance: waiterservice placefeature ["that's", 'frustrating', 'i', 'guess', 'i', 'will', 'call', 'them', 'can', 'you', 'tell', 'me', 'if', "benjy's", 'in', 'houston', 'has', 'waiter', 'service']
# not found in user utterance: waiterservice placefeature ['does', 'm3', 'in', 'reno', 'have', 'waiters']
# not found in user utterance: newyearseve holiday ['can', 'you', 'tell', 'me', 'what', 'day', 'new', 'years', 'eve', 'will', 'be', 'on', 'this', 'year']
# not found in user utterance: summarize weatherquantifier ["what's", 'the', 'temperature', 'today']
# not found in user utterance: sunrisetime weatherprop ['will', 'the', 'sun', 'come', 'out', 'today']
# not found in user utterance: summarize weatherquantifier ['will', 'the', 'sun', 'come', 'out', 'today']
# not found in user utterance: sunsettime weatherprop ['when', 'will', 'the', 'sun', 'set']
# not found in user utterance: summarize weatherquantifier ['when', 'will', 'the', 'sun', 'set']
# not found in user utterance: output path ['please', 'make', 'sure', 'the', 'breakfast', 'club', 'is', 'scheduled', 'from', '11', 'am', 'to', '12pm']
# not found in user utterance: output path ['what', 'about', 'this', 'weekend']
# not found in user utterance: fullbar placefeature ['do', 'they', 'serve', 'alcohol']
# not found in user utterance: june personname ['please', 'add', 'meeting', 'with', "june's", 'manager', 'on', 'saturday']
# not found in user utterance: june personname ['i', 'also', 'need', 'to', 'meet', 'with', "june's", 'manager', 'tomorrow']
# not found in user utterance: output path ['yes', 'but', 'i', 'need', 'the', 'meeting', 'with', "june's", 'manager', 'to', 'last', 'a', 'hour']
# not found in user utterance: workingelsewhere showasstatus ['change', 'it', 'to', 'working', 'elsewhere']
# not found in user utterance: output path ['no', 'the', 'one', 'the', 'day', 'after']
# not found in user utterance: output path ['no', 'delete', 'the', 'one', 'the', 'day', 'before']
# not found in user utterance: output path ['change', 'time', 'to', '1', 'pm', 'to', '3', 'pm']
# not found in user utterance: [] list[path] ['cancel', 'the', 'second', 'one']
# not found in user utterance: output path ['oops', 'i', 'meant', 'my', 'quarterly', 'revenue', 'meeting']
# not found in user utterance: output path ['actually', 'that', 'needs', 'to', 'start', 'in', 'the', 'spring']
# not found in user utterance: output path ['please', 'extend', 'it', 'to', 'noon']
# not found in user utterance: outofoffice showasstatus ['alright', 'is', 'there', 'events', 'that', 'show', 'me', 'as', 'out', 'of', 'office', 'without', 'attendees', 'in', 'them']
# not found in user utterance: output path ['ok', 'what', 'about', 'for', 'next', 'week']
# not found in user utterance: accepted responsestatustype ['is', 'jack', 'going', 'to', 'be', 'at', 'the', 'hat', 'club', 'meeting']
# not found in user utterance: tuesday dayofweek ['set', 'up', 'a', 'lunch', 'with', 'gail', 'lisa', 'renee', 'patty', 'for', 'tues', 'at', 'noon']
# not found in user utterance: [] list[recipient] ['forward', 'it', 'to', 'her', 'please']
# not found in user utterance: output path ['it', 'will', 'start', 'at', '6', 'pm', 'on', 'friday']
# not found in user utterance: output path ['actually', 'make', 'it', 'with', 'sara', 'milly', 'joe', 'and', 'thom']
# not found in user utterance: tentativelyaccepted responsestatustype ['who', 'may', 'attend', 'the', 'staff', 'meeting', 'next', 'month']
# not found in user utterance: tentativelyaccepted responsestatustype ['who', 'is', 'a', 'maybe', 'for', 'bad', 'energy']
# not found in user utterance: tentativelyaccepted responsestatustype ['who', 'is', 'possibly', 'attending', 'the', 'hair', 'loss']
# not found in user utterance: true boolean ['do', 'i', 'have', 'any', 'available', 'time', 'on', 'tuesday']
# not found in user utterance: true boolean ['i', 'have', 'any', 'available', 'time', 'on', 'tuesday']
# not found in user utterance: output path ['make', 'it', 'from', '3', 'till', 'midnight']
# not found in user utterance: temperature weatherprop ['what', 'is', '17', 'c', 'in', 'farenheight']
# not found in user utterance: max weatherquantifier ['what', 'is', '17', 'c', 'in', 'farenheight']
# not found in user utterance: summarize weatherquantifier ['what', 'is', 'the', 'temperature', 'in', 'antarctica', 'today']
# not found in user utterance: rainprecipprobability weatherprop ['is', 'there', 'a', 'chance', 'of', 'rain']
# not found in user utterance: summarize weatherquantifier ['is', 'there', 'a', 'chance', 'of', 'rain']
# not found in user utterance: busy showasstatus ['i', 'need', 'to', 'have', 'a', 'conference', 'call', 'with', 'tokyo', 'tomorrow', 'at', '7', 'pm', 'and', 'please', 'mark', 'my', 'calendar', 'as', 'do', 'not', 'disturb']
# not found in user utterance: dr. personname ['put', 'the', 'subject', 'as', 'eye', 'doctor', 'appointment', 'with', 'dr', 'nikolas']
# not found in user utterance: [] list[path] ['rename', 'the', 'first', 'appointment', 'take', 'dog', 'to', 'vet']
# not found in user utterance: true boolean ['am', 'i', 'free', 'next', 'week']
# not found in user utterance: [] list[path] ['rename', 'the', 'second', 'appointment', 'movie', 'night', 'please']
# not found in user utterance: output path ['change', 'the', 'dinner', 'time', 'at', '8', '30', 'pm', 'to', '9', '30', 'pm']
# not found in user utterance: fullbar placefeature ['does', 'nanak', 'in', 'texas', 'have', 'a', 'bar']
# not found in user utterance: fullbar placefeature ['does', "maggiano's", 'in', 'bellevue', 'have', 'a', 'bar']
# not found in user utterance: fullbar placefeature ['does', 'sanctuary', 'in', 'iowa', 'city', 'have', 'a', 'full', 'bar']
# not found in user utterance: laborday holiday ['will', 'i', 'be', 'busy', 'over', 'labor', 'day', 'weekend']
# not found in user utterance: true boolean ['will', 'i', 'be', 'busy', 'over', 'labor', 'day', 'weekend']
# not found in user utterance: memorialday holiday ['ok', 'great', 'when', 'is', 'memorial', 'day', 'this', 'year']
# not found in user utterance: august month ['put', 'meeting', 'with', 'johnny', 'on', 'aug', '3']
# not found in user utterance: blackfriday holiday ['when', 'is', 'black', 'friday']
# not found in user utterance: workingelsewhere showasstatus ['the', 'weather', 'this', 'week', 'has', 'been', 'really', 'nice', 'i', 'want', 'to', 'go', 'golfing', 'today', 'at', '1', 'pm', 'mark', 'me', 'as', 'working', 'elsewhere']
# not found in user utterance: accepted responsestatustype ['who', 'is', 'attending', 'that']
# not found in user utterance: output path ['wait', 'it', 'need', 'to', 'be', 'in', 'june']
# not found in user utterance: output path ['yes', 'but', 'please', 'make', 'it', 'from', '2', '30', 'to', '3', '30', 'pm', 'instead']
# not found in user utterance: accepted responsestatustype ['let', 'it', 'be', 'known', 'that', 'i', 'accept', 'this', 'deed']
# not found in user utterance: accepted responsestatustype ['is', 'thomas', 'coming', 'to', 'my', 'skating', 'rink']
# not found in user utterance: october month ['is', 'gloriya', 'coming', 'to', 'the', 'meeting', 'on', 'oct', '29', '8', '00', 'am']
# not found in user utterance: accepted responsestatustype ['is', 'gloriya', 'coming', 'to', 'the', 'meeting', 'on', 'oct', '29', '8', '00', 'am']
# not found in user utterance: accepted responsestatustype ['thanks', 'is', 'erica', 'coming', 'to', 'the', 'important', 'work', 'meeting', 'tomorrow']
# not found in user utterance: accepted responsestatustype ['is', 'cindy', 'going', 'to', 'the', 'brunch', 'on', 'saturday']
# not found in user utterance: accepted responsestatustype ['will', 'dave', 'jones', 'be', 'joining', 'us', 'for', 'the', 'conference', 'on', 'monday']
# not found in user utterance: accepted responsestatustype ['good', 'is', 'daniel', 'coming', 'out', 'for', 'bbq', 'with', 'us', 'tonight']
# not found in user utterance: output path ['yes', 'please', 'add', 'the', 'location', 'pizza', 'parlor', 'to', 'the', 'event']
# not found in user utterance: output path ['please', 'make', 'the', 'event', 'two', 'hours', 'earlier']
# not found in user utterance: [] list[path] ['please', 'make', 'the', 'event', 'two', 'hours', 'earlier']
# not found in user utterance: start path ['please', 'make', 'the', 'event', 'two', 'hours', 'earlier']
# not found in user utterance: accepted responsestatustype ['is', 'alex', 'going', 'to', 'be', 'at', 'this', 'meeting']
# not found in user utterance: peter personname ['delete', 'the', 'event', 'where', "i'm", 'meeting', 'with', "peter's", 'manager', 'that', 'was', 'scheduled', 'for', 'tuesday', 'at', '8', '45', 'am']
# not found in user utterance: dave personname ['when', 'is', 'my', 'meeting', 'with', "dave's", 'manager']
# not found in user utterance: dave personname ['schedule', 'a', 'meeting', 'with', "dave's", 'manager', 'tomorrow']
# not found in user utterance: output path ["let's", 'start', 'it', 'at', '3']
# not found in user utterance: [] list[recipient] ['forward', 'this', 'to', 'karen']
# not found in user utterance: output path ['can', 'you', 'please', 'add', 'kim', 'and', 'elli', 'to', 'that']
# not found in user utterance: output path ['change', 'the', 'event', 'name', 'to', 'rocket', 'science']
# not found in user utterance: output path ['can', 'you', 'add', "abby's", 'team', 'to', 'this']
# not found in user utterance: abby personname ['can', 'you', 'add', "abby's", 'team', 'to', 'this']
# not found in user utterance: september month ['please', 'conform', 'meeting', 'with', 'damon', 'strater', 'abby', 'gonano', 'dan', 'marton', 'and', 'jesse', 'rosenfeld', 'on', 'sep', '30', 'mon', 'at', '2pm']
# not found in user utterance: output path ['change', 'the', 'dessert', 'time', 'at', '11', '00', 'am', '11', '30', 'am']
# not found in user utterance: output path ["that's", 'ok', 'can', 'you', 'invite', 'susan']
# not found in user utterance: output path ['no', 'make', 'it', 'on', 'aug', '3']
# not found in user utterance: august month ['no', 'make', 'it', 'on', 'aug', '3']
# not found in user utterance: output path ['please', 'change', 'title', 'to', 'meeting', 'with', 'trish', 'and', 'daemon', 'straeter']
# not found in user utterance: output path ['looks', 'good', 'invite', 'trish', 'lady', 'nero', 'and', 'dante']
# not found in user utterance: - string ['actually', 'change', 'that', 'name', 'to', 'dentist', 'appointment', 'cleaning']
# not found in user utterance: output path ['the', 'meeting', 'will', 'be', 'until', '4']
# not found in user utterance: output path ['i', 'have', 'other', 'things', 'to', 'do', 'on', 'october', '28', 'how', 'about', 'the', 'next', 'day']
# not found in user utterance: outofoffice showasstatus ['can', 'you', 'schedule', 'a', 'basketball', 'practice', 'from', '4', '30', 'to', '6', '30', 'pm', 'tonight', 'and', 'set', 'the', 'showas', 'status', 'as', 'out', 'of', 'office']
# not found in user utterance: [] list[recipient] ['forward', 'the', 'company', 'party', 'to', 'john']
# not found in user utterance: output path ['how', 'about', 'tommorow']
# not found in user utterance: output path ['no', 'it', 'needs', 'to', 'be', 'after', '3', '00', 'pm']
# not found in user utterance: rainprecipprobability weatherprop ['is', 'there', 'any', 'chance', 'of', 'rain', 'on', 'that', 'event']
# not found in user utterance: summarize weatherquantifier ['is', 'there', 'any', 'chance', 'of', 'rain', 'on', 'that', 'event']
# not found in user utterance: output path ['that', 'is', 'good', 'but', 'add', '15', 'minutes', 'to', 'interview', 'with', 'the', 'local', 'paper', 'on', 'friday', 'to', 'make', 'it', '9', '00', 'to', '9', '45', 'am']
# not found in user utterance: abby personname ['schedule', 'another', 'meeting', 'this', 'coming', 'monday', 'with', "abby's", 'team', 'just', 'right', 'after', 'the', 'staff', 'meeting']
# not found in user utterance: jim personname ['how', 'about', 'we', 'schedule', 'something', 'with', "jim's", 'team', 'after', 'the', 'lunch', 'on', 'monday']
# not found in user utterance: accepted responsestatustype ['great', 'will', 'anyone', 'be', 'joining', 'mario', 'for', 'the', 'meeting']
# not found in user utterance: output path ['what', 'about', 'friday']
# not found in user utterance: output path ['what', 'about', 'the', 'luncheon', 'on', 'saturday']
# not found in user utterance: happyhour placefeature ['hello', 'does', "stella's", 'in', 'bellevue', 'have', 'happy', 'hour']
# not found in user utterance: happyhour placefeature ['hmmm', 'does', 'chapel', 'tavern', 'in', 'reno', 'have', 'a', 'happy', 'hour']
# not found in user utterance: happyhour placefeature ['can', 'you', 'let', 'me', 'know', 'if', "nick's", 'roast', 'beef', 'in', 'marlborough', 'has', 'a', 'happy', 'hour']
# not found in user utterance: party string ['who', 'is', 'the', 'organizer', 'to', 'birthday']
# not found in user utterance: output path ['fine', 'bring', 'in', 'david', 'lax', 'and', 'his', 'team', 'on', 'it', 'to', 'though']
# not found in user utterance: output path ['i', 'need', 'kim', 'and', 'her', 'team', 'as', 'well']
# not found in user utterance: d.c. locationkeyphrase ['what', 'will', 'the', 'weather', 'be', 'like', 'that', 'day', 'in', 'washington', 'd', 'c']

# %%
valid_params, valid_lispress_params, _ = add_parameters(valid,valid_lispress)
# Out:
# not found in user utterance: output path ['can', 'we', 'do', 'that', 'at', 'around', '8', 'instead']
# not found in user utterance: output path ['actually', 'i', 'changed', 'my', 'mind', 'to', 'be', 'around', '5', 'pm', 'could', 'you', 'do', 'that', 'instead']
# not found in user utterance: oak, locationkeyphrase ['what', 'is', 'the', 'weather', 'in', 'live', 'oak', 'fl']
# not found in user utterance: oak, locationkeyphrase ['tell', 'me', "tomorrow's", 'weather', 'for', 'live', 'oak', 'fl']
# not found in user utterance: city, locationkeyphrase ['will', 'i', 'need', 'to', 'wear', 'a', 'coat', 'this', 'weekend', 'in', 'lake', 'city', 'florida']
# not found in user utterance: city, locationkeyphrase ['i', 'want', 'to', 'know', 'the', 'weather', 'in', 'lake', 'city', 'fl']
# not found in user utterance: jacksonville, locationkeyphrase ['give', 'me', 'next', "week's", 'forecast', 'in', 'jacksonville', 'florida']
# not found in user utterance: oak, locationkeyphrase ['what', 'is', 'the', 'weather', 'forecast', 'for', 'the', 'next', '10', 'days', 'in', 'live', 'oak', 'florida']
# not found in user utterance: springs, locationkeyphrase ['i', 'want', 'to', 'go', 'fishing', 'tomorrow', 'in', 'high', 'springs', 'fl', 'can', 'i', 'do', 'that']
# not found in user utterance: springs, locationkeyphrase ['i', 'want', 'to', 'go', 'fishing', 'and', 'want', 'the', 'weather', 'for', 'high', 'springs', 'fl']
# not found in user utterance: oak, locationkeyphrase ['should', 'i', 'carry', 'an', 'umbrella', 'with', 'me', 'tomorrow', 'in', 'live', 'oak', 'fl']
# not found in user utterance: summarize weatherquantifier ['give', 'me', "tomorrow's", 'temperature', 'in', 'gainesville', 'fl']
# not found in user utterance: oak, locationkeyphrase ['should', 'i', 'wear', 'shorts', 'today', 'in', 'live', 'oak', 'fl']
# not found in user utterance: city, locationkeyphrase ['should', 'i', 'wear', 'short', 'sleeves', 'today', 'in', 'lake', 'city', 'fl']
# not found in user utterance: temperature weatherprop ["what's", 'the', 'temp', 'for', 'ft', 'white', 'fl']
# not found in user utterance: summarize weatherquantifier ["what's", 'the', 'temp', 'for', 'ft', 'white', 'fl']
# not found in user utterance: ft. locationkeyphrase ["what's", 'the', 'temp', 'for', 'ft', 'white', 'fl']
# not found in user utterance: temperature weatherprop ['what', 'is', "tomorrow's", 'temp', 'for', 'live', 'oak', 'florida']
# not found in user utterance: summarize weatherquantifier ['what', 'is', "tomorrow's", 'temp', 'for', 'live', 'oak', 'florida']
# not found in user utterance: oak, locationkeyphrase ['what', 'is', "tomorrow's", 'temp', 'for', 'live', 'oak', 'florida']
# not found in user utterance: orlando, locationkeyphrase ['i', 'need', 'to', 'know', 'if', 'i', 'should', 'pack', 'an', 'umbrella', 'tomorrow', 'in', 'orlando', 'fl']
# not found in user utterance: orlando, locationkeyphrase ["i'm", 'going', 'to', 'disney', 'world', 'this', 'weekend', 'in', 'orlando', 'fl', 'will', 'it', 'be', 'sunny']
# not found in user utterance: jacksonville, locationkeyphrase ['is', 'it', 'good', 'beach', 'weather', 'this', 'weekend', 'in', 'jacksonville', 'fl']
# not found in user utterance: orlando, locationkeyphrase ['give', 'me', 'the', 'weather', 'for', 'tomorrow', 'in', 'orlando', 'fl']
# not found in user utterance: jacksonville, locationkeyphrase ['is', 'it', 'good', 'beach', 'weather', 'this', 'weekend', 'in', 'jacksonville', 'fl']
# not found in user utterance: windspeed weatherprop ['how', 'about', 'the', 'wind']
# not found in user utterance: summarize weatherquantifier ['how', 'about', 'the', 'wind']
# not found in user utterance: mt. locationkeyphrase ['set', 'up', 'a', 'hike', 'for', '4', 'hours', 'on', 'saturday', 'at', '7am', 'on', 'mt', 'rainier']
# not found in user utterance: output path ['the', 'bbq', 'ends', 'at', '7']
# not found in user utterance: output path ["it's", 'on', 'the', '3rd', 'instead']
# not found in user utterance: output path ['5', '7', "doesn't", 'work', 'anymore', "we're", 'doing', '3', '5', 'now']
# not found in user utterance: true boolean ['what', 'time', 'i', 'am', 'free', 'in', 'my', 'schedule']
# not found in user utterance: declined responsestatustype ['decline', 'my', 'teaching', 'lesson', 'and', 'say', 'that', 'i', "don't", 'have', 'a', 'license']
# not found in user utterance: declined responsestatustype ['also', 'decline', 'the', 'invite', 'to', 'the', 'baseball', 'game', "it's", 'too', 'hot', 'outside']
# not found in user utterance: declined responsestatustype ['yes', "that's", 'good', 'decline', 'my', 'invitation', 'to', 'family', 'cookout', 'night', 'and', 'say', 'that', "i'm", 'going', 'on', 'a', 'date', 'that', 'evening', 'instead']
# not found in user utterance: august month ['put', 'meeting', 'with', 'glorry', 'at', 'aug', '11']
# not found in user utterance: accepted responsestatustype ['hello', 'who', 'is', 'my', 'zoom', 'meeting', 'with']
# not found in user utterance: output path ['what', 'about', 'the', 'tailgating', 'party']
# not found in user utterance: output path ['the', 'bbq']
# not found in user utterance: output path ['yes', 'but', 'also', 'add', 'gary', 'liam', 'and', 'penny']
# not found in user utterance: output path ['change', 'the', 'time', 'to', '9pm']
# not found in user utterance: output path ["we'll", 'be', 'leaving', 'at', 'midnight']
# not found in user utterance: output path ['no', '5pm', 'to', '6', '30', 'pm']
# not found in user utterance: [] list[path] ['what', 'about', 'saturday']
# not found in user utterance: time path ['what', 'about', 'saturday']
# not found in user utterance: output path ['what', 'about', 'the', 'next', 'day']
# not found in user utterance: [] list[path] ['choose', 'the', '3rd', 'one']
# not found in user utterance: output path ['yes', 'add', 'joe', 'to', 'that', 'event']
# not found in user utterance: output path ['could', 'you', 'actually', 'move', 'that', 'to', '1', 'please']
# not found in user utterance: output path ['can', 'we', 'please', 'make', 'it', 'only', '15', 'minutes']
# not found in user utterance: max weatherquantifier ['will', 'the', 'temperature', 'break', '100', 'degrees', 'f', 'today']
# not found in user utterance: saturday dayofweek ['add', 'visit', 'moraine', 'state', 'park', 'to', "saturday's", 'calendar', 'from', '9', 'am', 'until', '2', 'pm']
# not found in user utterance: crim personname ['i', 'need', 'to', 'see', "crim's", 'team', 'but', 'not', 'abby']
# not found in user utterance: output path ['i', 'need', 'lax', 'team', 'without', 'kim']
# not found in user utterance: output path ['block', 'out', '4', 'hours', 'for', 'that']
# not found in user utterance: cathy personname ['what', 'time', 'is', 'my', 'meeting', 'with', 'manager', 'on', 'tuesday']
# not found in user utterance: temperature weatherprop ["what's", 'the', 'high', 'temp', 'in', 'dallas', 'today', 'in', 'f']
# not found in user utterance: max weatherquantifier ["what's", 'the', 'high', 'temp', 'in', 'dallas', 'today', 'in', 'f']
# not found in user utterance: memorialday holiday ['when', 'is', 'memorial', 'day']
# not found in user utterance: output path ['do', 'we', 'have', 'anything', 'available', 'on', 'saturday']
# not found in user utterance: output path ['no', 'it', 'should', 'be', 'on', 'the', '4th']
# not found in user utterance: output path ['move', 'it', 'to', 'saturday', 'please']
# not found in user utterance: output path ['i', 'need', 'a', 'time', 'slot', 'that', 'makes', 'sense', 'for', 'dinner', 'evening']
# not found in user utterance: output path ['anything', 'earlier']
# not found in user utterance: [] list[path] ['anything', 'earlier']
# not found in user utterance: start path ['anything', 'earlier']
# not found in user utterance: output path ['also', 'include', 'davis', 'yates']
# not found in user utterance: output path ['make', 'it', 'earlier']
# not found in user utterance: [] list[path] ['make', 'it', 'earlier']
# not found in user utterance: start path ['make', 'it', 'earlier']
# not found in user utterance: [] list[path] ['madison', 'wi']
# not found in user utterance: place path ['madison', 'wi']
# not found in user utterance: goodforgroups placefeature ['does', 'that', 'have', 'a', 'room', 'for', 'big', 'groups']
# not found in user utterance: goodforgroups placefeature ['will', 'that', 'be', 'able', 'to', 'seat', 'a', 'large', 'group', 'for', 'a', "child's", 'birthday']
# not found in user utterance: output path ['make', 'it', 'til', '10am']
# not found in user utterance: [] list[recipient] ['forward', 'the', 'event', 'to', 'lisa', 'phoebe', 'and', 'jennifer']
# not found in user utterance: output path ['please', 'make', 'sure', 'that', 'lenny', 'and', 'marshall', 'are', 'invited']
# not found in user utterance: sunsettime weatherprop ['what', 'time', 'will', 'the', 'sun', 'set', 'in', 'seattle']
# not found in user utterance: summarize weatherquantifier ['what', 'time', 'will', 'the', 'sun', 'set', 'in', 'seattle']
# not found in user utterance: summarize weatherquantifier ['what', 'is', 'the', 'humidity', 'in', 'seattle']
# not found in user utterance: valentinesday holiday ['what', 'else', 'do', 'i', 'have', 'between', 'today', 'and', 'the', 'sunday', 'before', "valentine's", 'day']
# not found in user utterance: february month ['decline', 'my', 'conference', 'on', 'feb', '29', '2020', 'and', 'say', 'sorry', 'i', 'have', 'a', 'doctors', 'appointment']
# not found in user utterance: declined responsestatustype ['decline', 'my', 'conference', 'on', 'feb', '29', '2020', 'and', 'say', 'sorry', 'i', 'have', 'a', 'doctors', 'appointment']
# not found in user utterance: accepted responsestatustype ['yes', "that's", 'fine', 'accept', 'my', 'invitation', 'to', 'visit', 'the', 'craft', 'fair', 'on', 'friday', 'and', 'say', 'that', "i'm", 'planning', 'on', 'buying', 'lots', 'of', 'cool', 'items', 'there']
# not found in user utterance: accepted responsestatustype ['perfect', 'can', 'you', 'go', 'ahead', 'and', 'accept', 'the', 'laser', 'tag', 'event', 'with', 'dan', 'let', 'him', 'know', 'ill', 'pick', 'him', 'up']
# not found in user utterance: accepted responsestatustype ['with', 'whom', 'am', 'i', 'having', 'lunch']
# not found in user utterance: accepted responsestatustype ['will', 'bob', 'be', 'at', 'the', 'appointment']
# not found in user utterance: stand string ['can', 'you', 'set', 'up', 'a', 'up', 'meeting', 'with', 'sean', 'on', 'april', '18th']
# not found in user utterance: mothersday holiday ['when', 'is', "mother's", 'day']
# not found in user utterance: output path ['can', 'you', 'make', 'it', 'in', 'evening']
# not found in user utterance: output path ['invite', 'andy', 'and', 'obama', 'please']
# not found in user utterance: july month ['i', 'ok', 'with', 'jul', '12', 'fri']
# not found in user utterance: accepted responsestatustype ['can', 'you', 'accept', 'that', 'for', 'me']
# not found in user utterance: january month ['do', 'i', 'have', 'an', 'event', 'called', 'buy', 'hallmark', 'cards', 'for', 'jan', '1st']
# not found in user utterance: output path ['how', 'about']
# not found in user utterance: august month ['put', 'the', 'doctor', 'appointment', 'at', 'aug', '10', '11', '00', 'am']
# not found in user utterance: output path ['no', 'i', 'meant', 'it', 'will', 'be', 'all', 'day']
# not found in user utterance: true boolean ['no', 'i', 'meant', 'it', 'will', 'be', 'all', 'day']
# not found in user utterance: output path ['that', 's', 'better', 'but', 'can', 'i', 'move', 'it', 'to', 'the', 'next', 'day', 'again', 'all', 'day']
# not found in user utterance: february month ['schedule', 'my', 'winter', 'vacation', 'from', 'feb', '13', 'to', 'feb', '20']
# not found in user utterance: february month ['schedule', 'my', 'winter', 'vacation', 'from', 'feb', '13', 'to', 'feb', '20']
# not found in user utterance: output path ['yes', 'go', 'ahead', 'and', 'add', 'abby', 'to', 'that', 'too']
# not found in user utterance: output path ['change', 'start', 'time', 'as', '3', 'pm']
# not found in user utterance: output path ['could', 'you', 'change', 'it', 'to', '5pm', '7pm']
# not found in user utterance: fullbar placefeature ['does', 'fogo', 'de', 'chao', 'in', 'cupertino', 'have', 'a', 'bar']
# not found in user utterance: fullbar placefeature ['cool', 'does', "duffy's", 'ale', 'house', 'in', 'reno', 'have', 'a', 'full', 'bar']
# not found in user utterance: fullbar placefeature ['does', "taylor's", 'in', 'loomis', 'have', 'a', 'full', 'bar']
# not found in user utterance: outofoffice showasstatus ['show', 'me', 'as', 'out', 'of', 'office', 'from', 'the', '1st', 'through', 'the', '4th']
# not found in user utterance: output path ['i', 'just', 'want', 'to', 'change', 'the', 'time', 'to', '2', '00', 'pm', 'to', '4', '00', 'pm', 'instead']
# not found in user utterance: output path ['add', 'brittany', 'too']
# not found in user utterance: output path ['yes', 'also', 'heard', 'jimmy', 'will', 'be', 'there', 'please', 'add', 'him', 'as', 'well']
# not found in user utterance: false boolean ['when', 'do', 'i', 'have', 'time', 'free', 'on', 'monday', 'after', '2pm', 'to', 'meet', 'with', 'hannah']
# not found in user utterance: [] list[path] ['the', 'one', 'in', 'roseville']
# not found in user utterance: place path ['the', 'one', 'in', 'roseville']
# not found in user utterance: & locationkeyphrase ['does', 'pizza', 'burgers', 'in', 'shoreline', 'have', 'takeout']
# not found in user utterance: & locationkeyphrase ['do', 'they', 'sell', 'takeout', 'at', "jersey's", 'great', 'food', 'spirits', 'in', 'shoreline']
# not found in user utterance: output path ['yes', 'but', 'could', 'you', 'make', 'it', 'an', 'hour']
# not found in user utterance: output path ['this', 'should', 'run', 'for', 'two', 'hours']
# not found in user utterance: output path ['no', 'i', 'want', 'it', 'from', 'the', '12th', 'to', 'the', '22nd']
# not found in user utterance: output path ['actually', 'on', 'second', 'thought', 'change', 'that', 'to', 'boogie', 'boarding', 'for', 'me']
# not found in user utterance: [] list[path] ['cancel', 'the', 'second', 'one']
# not found in user utterance: waiterservice placefeature ['does', 'pho', '777', 'in', 'reno', 'have', 'waiter', 'service']
# not found in user utterance: waiterservice placefeature ['does', 'texas', 'roadhouse', 'in', 'reno', 'have', 'waiter', 'service']
# not found in user utterance: waiterservice placefeature ['does', 'm3', 'in', 'reno', 'have', 'waiter', 'service']
# not found in user utterance: output path ['what', 'about', 'outside', 'reno']
# not found in user utterance: b-day string ['can', 'you', 'create', 'an', 'event', 'called', "sister's", '21st', 'b', 'day', 'party', 'for', 'next', 'friday']
# not found in user utterance: output path ['make', 'dinner', 'with', 'to', 'be', 'with']
# not found in user utterance: output path ['please', 'add', 'chelsea', 'to', 'dinner', 'with', 'megan', 'and', 'remove']
# not found in user utterance: & locationkeyphrase ['do', 'i', 'have', 'another', 'lunch', 'meeting', 'this', 'week', 'that', 'is', 'not', 'at', 'duck', 'waffle']
# not found in user utterance: output path ['no', 'make', 'it', 'go', 'to', '4']
# not found in user utterance: output path ['looks', 'better', 'but', 'i', 'actually', 'want', 'it', 'to', 'start', 'at', '4', 'instead']
# not found in user utterance: chili's locationkeyphrase ['cancel', 'my', 'lunch', 'meeting', 'on', 'tuesday', 'at', 'two', 'and', 'reschedule', 'it', 'for', 'friday', 'at', '12', 'change', 'the', 'location', 'from', 'chili’s', 'to', 'applebee’s']
# not found in user utterance: applebee's locationkeyphrase ['cancel', 'my', 'lunch', 'meeting', 'on', 'tuesday', 'at', 'two', 'and', 'reschedule', 'it', 'for', 'friday', 'at', '12', 'change', 'the', 'location', 'from', 'chili’s', 'to', 'applebee’s']
# not found in user utterance: output path ['it', 'should', 'start', 'at', '6', 'pm', 'tonight', 'with', 'emily', 'bob', 'and', 'bill']
# not found in user utterance: output path ['make', 'it', 'until', '6']
# not found in user utterance: output path ['no', 'add', 'barack', 'obama']
# not found in user utterance: mt. locationkeyphrase ['i', 'a', 'hike', 'at', '7am', 'on', 'mt', 'rainier']
# not found in user utterance: temperature weatherprop ['is', 'it', 'going', 'to', 'be', 'warmer', 'on', 'the', 'same', 'day', 'next', 'week']
# not found in user utterance: summarize weatherquantifier ['is', 'it', 'going', 'to', 'be', 'warmer', 'on', 'the', 'same', 'day', 'next', 'week']
# not found in user utterance: temperature weatherprop ['is', 'it', 'going', 'to', 'be', 'warmer', 'on', 'the', 'same', 'day', 'next', 'week']
# not found in user utterance: summarize weatherquantifier ['is', 'it', 'going', 'to', 'be', 'warmer', 'on', 'the', 'same', 'day', 'next', 'week']
# not found in user utterance: january month ['set', 'date', 'for', 'jan', '14th', 'also', 'schedule', 'a', 'meeting', 'with', 'elli', 'jake', 'and', 'his', 'boss', 'for', 'friday']
# not found in user utterance: output path ['how', 'about', 'any', 'tennis', 'games']
# not found in user utterance: tentativelyaccepted responsestatustype ['who', 'is', 'possibly', 'attending', 'my', 'lecture', 'on', 'monday']
# not found in user utterance: tentativelyaccepted responsestatustype ['is', 'anyone', 'perhaps', 'attending', 'my', 'stand', 'up', 'routine']
# not found in user utterance: tentativelyaccepted responsestatustype ['can', 'you', 'see', 'who', 'is', 'possibly', 'coming', 'to', 'therapy']
# not found in user utterance: true boolean ['excellent', 'can', 'you', 'make', 'it', 'an', 'all', 'day', 'event']
# not found in user utterance: output path ['yes', 'but', 'please', 'have', 'it', 'last', '2', 'hours', 'instead']
# not found in user utterance: [] list[recipient] ['can', 'you', 'forward', 'it', 'to', 'her']
# not found in user utterance: friday dayofweek ['i', 'need', 'to', 'move', "friday's", 'meeting', 'to', 'monday', 'at', 'the', 'same', 'time']
# not found in user utterance: basketball string ['make', 'the', 'baseball', 'game', 'go', 'to', 'noon']
# not found in user utterance: output path ['that', 'is', 'correct', 'but', 'it', 'will', 'last', '2', 'hours']
# not found in user utterance: output path ['oh', 'i', 'meant', 'the', 'dinner', 'tomorrow']
# not found in user utterance: output path ['i', 'meant', 'the', 'remodel', 'basement', 'in', 'may']
# not found in user utterance: output path ['sorry', 'i', 'meant', 'my', 'new', 'apartment', 'event', 'in', 'may']
# not found in user utterance: output path ['that', 'looks', 'great', 'but', 'since', 'its', 'a', 'root', 'canal', 'make', 'it', 'two', 'hours', 'long']
# not found in user utterance: output path ['is', 'there', 'anyway', 'you', 'can', 'move', 'it', 'to', '3', '30pm', 'please']
# not found in user utterance: output path ['whoops', 'i', 'meant', 'to', 'have', 'that', 'be', 'in', 'winter']
# not found in user utterance: accepted responsestatustype ['did', 'i', 'accept', 'the', 'invitation', 'to', 'the', 'picnic']
# not found in user utterance: accepted responsestatustype ['did', 'randy', 'accept']
# not found in user utterance: emily personname ['when', 'is', 'the', 'meeting', 'between', 'me', 'and', "emily's", 'boss']
# not found in user utterance: output path ['invite', 'tony', 'and', 'peter', 'as', 'well', 'please']
# not found in user utterance: output path ['yes', 'but', 'rose', "can't", 'make', 'it', 'can', 'you', 'remove', 'rose']
# not found in user utterance: output path ['yes', 'and', 'please', 'invite', 'grandma', 'charlotte', 'to', 'the', 'event']
# not found in user utterance: output path ['change', 'the', 'time', 'to', '4pm']
# not found in user utterance: dr. personname ['add', 'appointment', 'with', 'dr', 'snow', 'to', 'my', 'calendar', 'on', 'thursday', 'at', '4', 'p', 'm']
# not found in user utterance: output path ['make', 'that', 'from', '10', 'to', '11', 'am']
# not found in user utterance: output path ['i', 'meant', '12', 'pm']
# not found in user utterance: jake personname ['i', 'need', 'to', 'schedule', 'a', 'coffee', 'date', 'with', "jake's", 'skip']
# not found in user utterance: output path ['please', 'add', "kim's", 'skip']
# not found in user utterance: kim personname ['please', 'add', "kim's", 'skip']
# not found in user utterance: toronto locationkeyphrase ['what', 'do', 'i', 'have', 'on', 'october', '20', '2020', 'that', "isn't", 'in']
# not found in user utterance: [] list[path] ['can', 'we', 'do', 'dinner', 'a', 'little', 'earlier', 'than', 'that']
# not found in user utterance: start path ['can', 'we', 'do', 'dinner', 'a', 'little', 'earlier', 'than', 'that']
# not found in user utterance: output path ['what', 'about', 'the', 'following', 'thursday']
# not found in user utterance: dr. personname ['do', 'i', 'have', 'an', 'eye', 'exam', 'with', 'dr', 'rock', 'on', 'friday']
# not found in user utterance: output path ['it', 'should', 'last', 'for', '4', 'days']
# not found in user utterance: [] list[path] ['it', 'should', 'last', 'for', '4', 'days']
# not found in user utterance: start path ['it', 'should', 'last', 'for', '4', 'days']
# not found in user utterance: thursday dayofweek ['add', 'a', 'meeting', 'at', '230', 'pm', 'this', 'thusday', 'with', 'karl', 'boon']
# not found in user utterance: output path ['it', 'needs', 'to', 'be', '3', 'hours', 'long']
# not found in user utterance: output path ['no', 'make', 'it', 'end', 'at', '3']
# not found in user utterance: declined responsestatustype ['decline', 'the', 'pitch', 'meeting', 'for', 'thursday']
# not found in user utterance: [] list[path] ['please', 'delete', 'the', 'first', 'event']
# not found in user utterance: output path ['make', 'it', 'last', 'until', '11', '15', 'am']
# not found in user utterance: summarize weatherquantifier ['i', 'would', 'like', 'to', 'know', 'what', 'the', 'temperature', 'will', 'be', 'tomorrow']
# not found in user utterance: output path ['make', 'it', 'last', 'one', 'hour']
# not found in user utterance: output path ['great', 'and', 'add', 'elizabeth', 'to', 'the', 'meeting']
# not found in user utterance: august month ['do', 'i', 'have', 'anything', 'else', 'the', 'afternoon', 'of', 'aug', '1']
# not found in user utterance: output path ['sorry', 'make', 'it', 'until', 'sunday', 'and', 'mark', 'me', 'as', 'busy']
# not found in user utterance: [] list[path] ['sorry', 'make', 'it', 'until', 'sunday', 'and', 'mark', 'me', 'as', 'busy']
# not found in user utterance: end path ['sorry', 'make', 'it', 'until', 'sunday', 'and', 'mark', 'me', 'as', 'busy']
# not found in user utterance: output path ['what', 'about', 'that', 'evening']
# not found in user utterance: valentinesday holiday ['what', 'date', 'was', "valentine's", 'day', 'in']
# not found in user utterance: memorialday holiday ['when', 'is', 'memorial', 'day']
# not found in user utterance: output path ['anything', 'sooner']
# not found in user utterance: [] list[path] ['anything', 'sooner']
# not found in user utterance: start path ['anything', 'sooner']
# not found in user utterance: output path ['that', 'should', 'go', 'until', '1', '30']
# not found in user utterance: output path ['can', 'you', 'change', 'that', 'to', 'monday', 'we', "don't", 'want', 'to', 'spend', 'the', 'weekend', 'in', 'a', 'store']
# not found in user utterance: output path ["that's", 'going', 'to', 'be', 'a', 'dentist', 'appointment', 'and', 'it', 'should', 'go', 'until', '4', '15', 'pm']
# not found in user utterance: output path ['mark', 'me', 'as', 'out', 'of', 'the', 'office', 'during', 'that', 'time']
# not found in user utterance: outofoffice showasstatus ['mark', 'me', 'as', 'out', 'of', 'the', 'office', 'during', 'that', 'time']
# not found in user utterance: output path ['it', 'should', 'be', 'another', '20', 'minutes', 'longer']
# not found in user utterance: start path ['add', "mark's", 'bachelor', 'party', 'to', 'my', 'calendar', 'for', 'this', 'saturday', 'between', '5', 'and', '11', 'pm']
# not found in user utterance: event path ['add', "mark's", 'bachelor', 'party', 'to', 'my', 'calendar', 'for', 'this', 'saturday', 'between', '5', 'and', '11', 'pm']
# not found in user utterance: + string ['yes', 'also', 'add', 'watch', 'disney', 'next', 'year']
# not found in user utterance: output path ['no', 'it', 'was', 'last', 'thursday']
# not found in user utterance: output path ['yes', 'but', 'it', 'was', 'at', '10', 'am', 'not', 'pm']
# not found in user utterance: output path ['yes', 'but', 'add', 'mark', 'and', 'carlos', 'to', 'this', 'event']
# not found in user utterance: true boolean ['am', 'i', 'free', 'on', 'friday', 'afternoon']
# not found in user utterance: true boolean ['am', 'i', 'free', 'on', 'monday', 'afternoon']
# not found in user utterance: independenceday holiday ['add', 'make', 'table', '3', 'days', 'before', 'independence', 'day', 'start', 'at', '10am', 'and', "i'll", 'need', '3', 'hours', 'to', 'do', 'them']
# not found in user utterance: output path ['no', '8', 'pm', 'until', '10', 'pm']
# not found in user utterance: outofoffice showasstatus ['mark', 'me', 'as', 'out', 'of', 'office', 'for', 'march', '7', '12th']
# not found in user utterance: [] list[path] ['what', 'about', 'tomorrow']
# not found in user utterance: time path ['what', 'about', 'tomorrow']
# not found in user utterance: min weatherquantifier ["what's", 'the', 'low', 'temperature', 'for', 'sunday']
# not found in user utterance: temperature weatherprop ['celsius']
# not found in user utterance: max weatherquantifier ['celsius']
# not found in user utterance: temperature weatherprop ['celsius']
# not found in user utterance: min weatherquantifier ['celsius']
# not found in user utterance: output path ['good', 'extend', 'the', 'times', 'square', 'for', 'one', 'hour']
# not found in user utterance: output path ['please', 'add', 'to', 'this', 'meeting']
# not found in user utterance: output path ["let's", 'make', 'it', 'an', 'hour', 'longer', 'than', 'that', 'though']
# not found in user utterance: happyhour placefeature ['tell', 'me', 'if', 'la', 'vara', 'in', 'brooklyn', 'has', 'a', 'happy', 'hour']
# not found in user utterance: happyhour placefeature ['see', 'if', 'there', 'is', 'a', 'happy', 'hour', 'at', "burt's", 'lounge', 'in', 'albuquerque']
# not found in user utterance: happyhour placefeature ['does', "shae's", 'tavern', 'in', 'reno', 'have', 'the', 'happy', 'hour', 'specials']
# not found in user utterance: output path ['actually', 'it', 'needs', 'to', 'be', 'much', 'later']
# not found in user utterance: [] list[path] ['actually', 'it', 'needs', 'to', 'be', 'much', 'later']
# not found in user utterance: start path ['actually', 'it', 'needs', 'to', 'be', 'much', 'later']
# not found in user utterance: output path ['actually', 'make', 'that', '3', '4']
# not found in user utterance: nick personname ['where', 'am', 'i', 'meeting', 'with', "nick's", 'manager', 'on', 'july', '29th']
# not found in user utterance: valentinesday holiday ['setup', 'a', 'planning', 'night', 'meeting', 'for', 'the', 'day', 'before', 'valentines', 'day', 'at', '3', 'pm', 'that', 'should', 'last', '2', 'hours', 'and', 'mark', 'it', 'busy']
# not found in user utterance: accepted responsestatustype ['can', 'you', 'accept', 'my', 'golf', 'trip']
# not found in user utterance: accepted responsestatustype ['would', 'you', 'please', 'accept', 'the', 'met', 'gala', 'for', 'tomorrow']
# not found in user utterance: l@l string ['yes', 'then', 'could', 'you', 'accept', 'the', 'l', 'l', 'for', 'next', 'week']
# not found in user utterance: accepted responsestatustype ['yes', 'then', 'could', 'you', 'accept', 'the', 'l', 'l', 'for', 'next', 'week']
# not found in user utterance: wednesday dayofweek ['will', 'it', 'rain', 'weds', 'in', 'vienna', 'oh']
# not found in user utterance: summarize weatherquantifier ['what', 'will', 'the', 'temperature', 'be', 'in', 'weds', 'in', 'vienna', 'oh']
# not found in user utterance: wednesday dayofweek ['what', 'will', 'the', 'temperature', 'be', 'in', 'weds', 'in', 'vienna', 'oh']
# not found in user utterance: summarize weatherquantifier ['what', 'will', 'the', 'temperature', 'be', 'like', 'saturday', 'in', 'vienna', 'oh']
# not found in user utterance: output path ['no', 'later', 'than', 'that']
# not found in user utterance: [] list[path] ['no', 'later', 'than', 'that']
# not found in user utterance: start path ['no', 'later', 'than', 'that']
# not found in user utterance: output path ['oh', 'sorry', 'it', 'is', 'saturdays', 'run', 'we', "aren't", 'going', 'to', 'do']
# not found in user utterance: saturday dayofweek ['oh', 'sorry', 'it', 'is', 'saturdays', 'run', 'we', "aren't", 'going', 'to', 'do']
# not found in user utterance: accepted responsestatustype ['hello', 'is', 'diane', 'coming', 'to', 'the', 'birthday', 'celebration', 'next', 'thursday']
# not found in user utterance: accepted responsestatustype ['great', 'is', 'jamie', 'coming', 'to', 'the', 'sales', 'meeting', 'today']
# not found in user utterance: accepted responsestatustype ['okay', 'will', 'chris', 'be', 'at', 'the', 'staff', 'meeting', 'on', 'wednesday']
# not found in user utterance: accepted responsestatustype ['okay', 'will', 'jean', 'be', 'at', 'the', 'staff', 'meeting', 'tomorrow', 'morning']
# not found in user utterance: accepted responsestatustype ['oh', 'okay', 'is', 'susan', 'coming', 'to', 'the', 'event', 'was', 'scheduled', 'for', 'tomorrow']
# not found in user utterance: output path ['add', 'jimmy', 'to', 'lunch', 'also']
# not found in user utterance: output path ['make', 'it', 'last', '1', '5', 'hours']
# not found in user utterance: output path ['alter', 'the', 'date', 'the', 'monday']
# not found in user utterance: [] list[path] ['alter', 'the', 'date', 'the', 'monday']
# not found in user utterance: start path ['alter', 'the', 'date', 'the', 'monday']
# not found in user utterance: output path ['change', 'the', 'date', 'of', 'lunch', 'to', 'june', '22nd']
# not found in user utterance: output path ['can', 'you', 'make', 'it', 'in', '1', 'hour', 'instead']
# not found in user utterance: output path ['i', "can't", 'have', 'a', 'staff', 'meeting', 'at', 'midnight', 'move', 'it', 'to', '3', 'hours', 'from', 'now']
# not found in user utterance: tuesday dayofweek ['book', 'me', 'a', 'gym', 'session', 'tue', 'five', 'am']
# not found in user utterance: output path ['no', 'i', 'want', 'it', 'to', 'start', 'at', '6', 'instead']
# not found in user utterance: output path ['no', 'make', 'that', 'start', 'at', '7', '30']
# not found in user utterance: december month ['can', 'you', 'make', 'me', 'a', '19', 'days', 'vacation', 'starting', 'on', 'dec', '11']
# not found in user utterance: tom personname ['what', 'is', "tom's", 'phone', 'number']
# not found in user utterance: output path ['add', 'elli', 'and', 'her', 'team', 'to', 'this']
# not found in user utterance: rosenfeld personname ['thanks', 'now', 'set', 'a', 'training', 'session', 'with', 'jesse', "rosenfeld's", 'team', 'on', 'the', '21st']
# not found in user utterance: output path ['add', 'kim', 'and', 'her', 'team', 'to', 'this']
# not found in user utterance: output path ['make', 'it', '3', 'hours']
# not found in user utterance: output path ['no', 'can', 'you', 'make', 'that', '2', 'hours']
# not found in user utterance: output path ['oh', 'and', 'please', 'add', 'sylvia', 'simmons']
# not found in user utterance: merlot's locationkeyphrase ['change', 'my', 'lunch', 'next', 'friday', 'to', 'the', 'location', 'of', 'eddie', 'merlot’s', 'and', 'also', 'change', 'the', 'time', 'from', '1130', 'till', '12', 'pm']
# not found in user utterance: output path ['yes', 'but', "i'll", 'be', 'riding', 'until', '1100']
# not found in user utterance: output path ['i', 'meant', 'this', 'week']
# not found in user utterance: output path ['what', 'about', 'next', 'week']
# not found in user utterance: output path ['it', 'should', 'be', 'an', 'hour', 'long']
# not found in user utterance: outdoordining placefeature ["there's", 'outside', 'seating', 'correct']
# not found in user utterance: familyfriendly placefeature ['is', 'it', 'okay', 'for', 'children']
# not found in user utterance: fullbar placefeature ['does', 'this', 'restaurant', 'serve', 'alcohol']
# not found in user utterance: accepted responsestatustype ['is', 'jane', 'coming', 'for', 'the', 'meeting']
# not found in user utterance: keith personname ['please', 'schedule', 'an', 'hour', 'long', 'meeting', 'with', 'team', 'directly', 'after', 'the', 'morning', 'meeting']
# not found in user utterance: output path ['what', 'about', 'november', '25', 'from', '6', '33', 'am', 'to', '8', '35', 'pm']
# not found in user utterance: output path ['invite', 'ronald', 'instead']
# not found in user utterance: output path ['we', 'actually', "don't", 'need', 'linda', 'anymore']
# not found in user utterance: output path ['needs', '30', 'more', 'minutes']
# not found in user utterance: newyearsday holiday ['what', 'is', 'the', 'weather', 'in', 'michigan', 'for', 'new', 'years']
# not found in user utterance: accepted responsestatustype ['please', 'accept', 'the', 'bowling', 'fundraiser', 'and', 'tell', 'sammy', 'i', 'will', 'bring', 'refreshments']
# not found in user utterance: i respondcomment ['yes', "that's", 'good', 'accept', 'community', 'planning', 'meeting', 'and', 'say', 'that', "i'm", 'excited', 'to', 'talk', 'about', 'our', 'plans', 'for', 'the', 'new', 'park']
# not found in user utterance: will respondcomment ['yes', "that's", 'good', 'accept', 'community', 'planning', 'meeting', 'and', 'say', 'that', "i'm", 'excited', 'to', 'talk', 'about', 'our', 'plans', 'for', 'the', 'new', 'park']
# not found in user utterance: bring respondcomment ['yes', "that's", 'good', 'accept', 'community', 'planning', 'meeting', 'and', 'say', 'that', "i'm", 'excited', 'to', 'talk', 'about', 'our', 'plans', 'for', 'the', 'new', 'park']
# not found in user utterance: refreshments respondcomment ['yes', "that's", 'good', 'accept', 'community', 'planning', 'meeting', 'and', 'say', 'that', "i'm", 'excited', 'to', 'talk', 'about', 'our', 'plans', 'for', 'the', 'new', 'park']
# not found in user utterance: bowling string ['yes', "that's", 'good', 'accept', 'community', 'planning', 'meeting', 'and', 'say', 'that', "i'm", 'excited', 'to', 'talk', 'about', 'our', 'plans', 'for', 'the', 'new', 'park']
# not found in user utterance: fundraiser string ['yes', "that's", 'good', 'accept', 'community', 'planning', 'meeting', 'and', 'say', 'that', "i'm", 'excited', 'to', 'talk', 'about', 'our', 'plans', 'for', 'the', 'new', 'park']
# not found in user utterance: accepted responsestatustype ['yes', "that's", 'good', 'accept', 'community', 'planning', 'meeting', 'and', 'say', 'that', "i'm", 'excited', 'to', 'talk', 'about', 'our', 'plans', 'for', 'the', 'new', 'park']
# not found in user utterance: accepted responsestatustype ['yes', 'that', 'looks', 'right', 'i', 'need', 'to', 'accept', 'office', 'food', 'shopping', 'on', 'march', '20', '2020']
# not found in user utterance: output path ['can', 'you', 'have', 'it', 'go', 'until', '2', 'pm']
# not found in user utterance: accepted responsestatustype ["i'll", 'accept', 'that', 'meeting']
# not found in user utterance: output path ['good', 'actually', 'i', 'forgot', 'can', 'you', 'add', 'angelina', 'to', 'that', 'meeting', 'too']
# not found in user utterance: winifred personname ['am', 'i', 'meeting', 'with', 'mary', 'and', 'sarah', 'tomorrow']
# not found in user utterance: output path ['yes', 'add', 'the', 'mall', 'theater', 'as', 'the', 'location']
# not found in user utterance: output path ['i', 'meant', 'am', 'my', 'bad']
# not found in user utterance: [] list[path] ['i', 'meant', 'am', 'my', 'bad']
# not found in user utterance: start path ['i', 'meant', 'am', 'my', 'bad']
# not found in user utterance: output path ['i', 'meant', 'am']
# not found in user utterance: [] list[path] ['i', 'meant', 'am']
# not found in user utterance: start path ['i', 'meant', 'am']
# not found in user utterance: output path ['i', 'meant', 'pm']
# not found in user utterance: [] list[path] ['i', 'meant', 'pm']
# not found in user utterance: start path ['i', 'meant', 'pm']
# not found in user utterance: output path ['thanks', 'go', 'ahead', 'and', 'schedule', 'that', 'meeting', 'until', '3', 'pm']
# not found in user utterance: [] list[path] ['what', 'time', 'was', 'the', 'first', 'one']
# not found in user utterance: output path ['can', 'you', 'have', 'it', 'go', 'to', '12', 'pm']
# not found in user utterance: output path ['no', 'extend', 'it', 'to', '2pm']
# not found in user utterance: accepted responsestatustype ['do', 'i', 'have', 'any', 'attendees', 'come', 'to', 'the', 'event', 'on', 'thursday']
# not found in user utterance: monday dayofweek ['have', "monday's", 'appointment', 'showas', 'busy']
# not found in user utterance: output path ['oh', 'yeah', 'make', 'it', 'sometime', 'in', 'the', 'summer']
# not found in user utterance: output path ['lets', 'go', 'late', 'summer']
# not found in user utterance: output path ['what', 'about', 'tomorrow']
# not found in user utterance: output path ['actually', 'change', 'time', 'to', '12', '30', 'pm']
# not found in user utterance: output path ['change', 'the', 'time', 'to', '9pm']
# not found in user utterance: dr. personname ['move', 'the', 'lecture', 'with', 'dr', 'rogers', 'to', '1', 'pm', 'tomorrow', 'afternoon']
# not found in user utterance: output path ['have', 'it', 'end', 'at', 'three']
# not found in user utterance: output path ['i', 'meant', 'snow', 'skiing', 'lesson']
# not found in user utterance: output path ['no', 'make', 'it', 'for', 'this', 'week']
# not found in user utterance: output path ['no', 'it', 'should', 'be', 'an', 'hour', 'long']
# not found in user utterance: output path ['actually', 'just', '55', 'minutes', 'long', 'please']
# not found in user utterance: output path ['no', 'i', 'want', 'it', 'on', 'monday']
# not found in user utterance: accepted responsestatustype ['accept', 'the', 'invitation', 'to', 'play', 'smash']
# not found in user utterance: accepted responsestatustype ['while', "you're", 'at', 'it', 'accept', 'my', 'invitation', 'to', 'the', 'soccer', 'game']
# not found in user utterance: accepted responsestatustype ['accept', 'the', 'staff', 'review', 'and', 'say', 'that', 'i', 'have', 'a', 'lot', 'of', 'concerns', 'to', 'address']
# not found in user utterance: declined responsestatustype ['please', 'decline', 'my', 'meeting', 'in', 'saturday']
# not found in user utterance: accepted responsestatustype ['accept', 'the', 'party', 'invite', 'and', 'let', 'them', 'know', 'i', 'will', 'bring', 'a', 'bottle', 'of', 'wine']
# not found in user utterance: january month ["that's", 'fine', 'could', 'you', 'decline', 'the', 'meeting', 'with', 'jake', 'on', 'jan', '1st']
# not found in user utterance: declined responsestatustype ["that's", 'fine', 'could', 'you', 'decline', 'the', 'meeting', 'with', 'jake', 'on', 'jan', '1st']
# not found in user utterance: output path ['how', 'about', 'after', '5', 'days']
# not found in user utterance: jake personname ['who', 'is', 'on', "jake's", 'team']
# not found in user utterance: jake personname ['make', 'an', 'event', 'with', "jake's", 'team', 'make', 'it', 'on', 'monday', 'afternoon']
# not found in user utterance: output path ['wait', 'wait', 'wait', 'i', 'meant', 'the', 'whole', 'weekend']
# not found in user utterance: wednesday dayofweek ['do', 'i', 'have', 'anything', 'for', 'wed', 'night']
# not found in user utterance: meeting string ['are', 'there', 'any', 'board', 'meetings', 'late', 'this', 'week']
# not found in user utterance: output path ['what', 'about', 'next', 'month']
# not found in user utterance: output path ['what', 'about', 'november']
# not found in user utterance: output path ['oh', 'and', 'add', 'abby', 'kim', 'jake', 'and', 'jesse', 'to', 'that', 'please']
# not found in user utterance: output path ['that', 'looks', 'correct', 'but', 'it', 'should', 'be', '45', 'minutes', 'long']
# not found in user utterance: output path ['actually', 'not', 'during', 'the', 'weekend', "i'm", 'busy', 'at', 'that', 'time']
# not found in user utterance: output path ['so', 'the', 'weekend', 'is', 'a', 'no', 'go', 'so', 'change', 'it']
# not found in user utterance: output path ['no', 'lets', 'not', 'do', 'the', 'weekend']
# not found in user utterance: tom personname ['hello', 'who', 'is', "tom's", 'manager']
# not found in user utterance: output path ['can', 'you', 'add', "dan's", 'manager', 'too']
# not found in user utterance: dan personname ['can', 'you', 'add', "dan's", 'manager', 'too']
# not found in user utterance: rainprecipprobability weatherprop ['is', 'there', 'a', 'chance', 'for', 'rain', 'during', 'my', 'picnic', 'next', 'week']
# not found in user utterance: summarize weatherquantifier ['is', 'there', 'a', 'chance', 'for', 'rain', 'during', 'my', 'picnic', 'next', 'week']
# not found in user utterance: output path ['set', 'the', 'location', 'to', "pike's", 'place', 'market']
# not found in user utterance: st. locationkeyphrase ['schedule', 'city', 'tour', 'for', '1', 'pm', 'on', 'friday', 'at', 'st', 'fl']
# not found in user utterance: [] list[path] ['what', 'about', 'saturday']
# not found in user utterance: time path ['what', 'about', 'saturday']
# not found in user utterance: [] list[path] ['what', 'about', 'the', '29th']
# not found in user utterance: time path ['what', 'about', 'the', '29th']
# not found in user utterance: output path ['have', 'it', 'last', 'for', 'an', 'hour']
# not found in user utterance: accepted responsestatustype ['who', 'am', 'i', 'meeting', 'tomorrow']
# not found in user utterance: output path ['please', 'change', 'the', 'date', 'to', 'june', '6th', 'at', '2', 'pm', 'until', '4', '40pm']
# not found in user utterance: true boolean ['i', 'also', 'need', 'a', '1', '1', 'with', 'carla', 'at', '1', 'pm', 'today']
# not found in user utterance: output path ['change', 'the', 'time', 'to', '3pm']
# not found in user utterance: output path ['change', 'the', 'end', 'time', 'to', '3', '20']
# not found in user utterance: output path ['what', 'about', 'training']
# not found in user utterance: output path ['how', 'about', 'sales', 'pitch', 'meetings']
# not found in user utterance: output path ['and', 'sales', 'report', 'sessions']
# not found in user utterance: true boolean ['schedule', 'a', 'one', 'one', 'with', 'mike', 'for', 'later', 'this', 'week']
# not found in user utterance: temperature weatherprop ['which', 'day', 'is', 'going', 'to', 'be', 'hotter', 'saturday', 'or', 'sunday']
# not found in user utterance: max weatherquantifier ['which', 'day', 'is', 'going', 'to', 'be', 'hotter', 'saturday', 'or', 'sunday']
# not found in user utterance: temperature weatherprop ['which', 'day', 'is', 'going', 'to', 'be', 'hotter', 'saturday', 'or', 'sunday']
# not found in user utterance: max weatherquantifier ['which', 'day', 'is', 'going', 'to', 'be', 'hotter', 'saturday', 'or', 'sunday']
# not found in user utterance: tentativelyaccepted responsestatustype ['who', 'has', 'not', 'responded', 'with', 'a', 'tentative', 'for', 'brunch']
# not found in user utterance: output path ['no', 'i', 'will', 'need', 'it', 'at', '3pm']
# not found in user utterance: output path ['yes', 'but', 'it', 'got', 'delayed', 'and', 'started', 'at', '10', 'am', 'instead']
# not found in user utterance: friday dayofweek ['would', 'you', 'please', 'set', 'up', 'a', 'lunch', 'meeting', 'with', 'jerri', 'skinner', 'for', 'fri']
# not found in user utterance: output path ['no', 'can', 'you', 'set', 'up', 'something', 'closer', 'to', '12']
# not found in user utterance: declined responsestatustype ['who', 'is', 'not', 'declining', 'the', 'iphone', 'release', 'party']
# not found in user utterance: tentativelyaccepted responsestatustype ['who', 'has', 'not', 'tentativley', 'accpeted', 'happy', 'hour']
# not found in user utterance: fullbar placefeature ['does', 'applebees', 'in', 'fallon', 'have', 'a', 'full', 'bar']
# not found in user utterance: fullbar placefeature ['i', 'want', 'to', 'know', 'if', 'hy', 'yee', 'in', 'skiatook', 'has', 'full', 'bar']
# not found in user utterance: hy-yee locationkeyphrase ['i', 'want', 'to', 'know', 'if', 'hy', 'yee', 'in', 'skiatook', 'has', 'full', 'bar']
# not found in user utterance: fullbar placefeature ['does', 'applebees', 'in', 'carson', 'city', 'have', 'a', 'full', 'bar']
# not found in user utterance: rainprecipprobability weatherprop ['what', 'is', 'the', 'chance', 'of', 'rain', 'for', 'the', 'appointment']
# not found in user utterance: summarize weatherquantifier ['what', 'is', 'the', 'chance', 'of', 'rain', 'for', 'the', 'appointment']
# not found in user utterance: output path ['i', 'need', 'an', 'earlier', 'day']
# not found in user utterance: [] list[path] ['i', 'need', 'an', 'earlier', 'day']
# not found in user utterance: start path ['i', 'need', 'an', 'earlier', 'day']
# not found in user utterance: output path ['is', 'there', 'anything', 'later', 'in', 'the', 'day']
# not found in user utterance: [] list[path] ['is', 'there', 'anything', 'later', 'in', 'the', 'day']
# not found in user utterance: start path ['is', 'there', 'anything', 'later', 'in', 'the', 'day']
# not found in user utterance: output path ['a', 'later', 'appointment']
# not found in user utterance: [] list[path] ['a', 'later', 'appointment']
# not found in user utterance: start path ['a', 'later', 'appointment']
# not found in user utterance: [] list[path] ['the', 'last', 'event', 'will', 'take', '18', 'hours']
# not found in user utterance: output path ['please', 'schedule', 'it', 'earlier', 'in', 'the', 'day']
# not found in user utterance: [] list[path] ['please', 'schedule', 'it', 'earlier', 'in', 'the', 'day']
# not found in user utterance: start path ['please', 'schedule', 'it', 'earlier', 'in', 'the', 'day']
# not found in user utterance: abby personname ['do', 'i', 'have', 'a', 'meeting', 'scheduled', 'with', "abby's", "manager's", 'manager', 'tomorrow']
# not found in user utterance: jack personname ['that', 'time', 'is', 'okay', 'now', 'set', 'down', 'a', 'talk', 'with', "jack's", 'skip', 'tomorrow', 'morning']
# not found in user utterance: jack personname ['cancel', 'the', 'meeting', 'with', "jack's", 'skip', 'tomorrow']
# not found in user utterance: output path ['sorry', 'it', 'should', 'be', 'birthday']
# not found in user utterance: output path ['start', 'time', '11', '30']
# not found in user utterance: output path ['no', 'i', 'want', '5', 'pm']
# not found in user utterance: output path ['that', 'should', 'last', 'until', '6']
# not found in user utterance: output path ['lucy', 'needs', 'me', 'to', 'move', 'that', 'meeting', 'to', 'wednesday', 'same', 'time']
# not found in user utterance: true boolean ['when', 'do', 'i', 'next', 'have', 'an', 'all', 'day', 'event', 'with', 'clarice']
# not found in user utterance: possible personname ['when', 'do', 'i', 'meet', 'with', 'kim', "possible's", 'team']
# not found in user utterance: fullbar placefeature ['does', 'middlesex', 'diner', 'in', 'carlisle', 'have', 'a', 'full', 'bar']
# not found in user utterance: fullbar placefeature ['does', "taylor's", 'in', 'loomis', 'have', 'a', 'full', 'bar']
# not found in user utterance: fullbar placefeature ['haru', 'in', 'reno', 'full', 'bar']
# not found in user utterance: rainprecipprobability weatherprop ['is', 'there', 'any', 'chance', 'it', 'will', 'rain', 'during', 'the', 'party', 'at', 'the', 'ymca']
# not found in user utterance: summarize weatherquantifier ['is', 'there', 'any', 'chance', 'it', 'will', 'rain', 'during', 'the', 'party', 'at', 'the', 'ymca']
# not found in user utterance: summarize weatherquantifier ["what's", 'the', 'temperature', 'for', 'the', 'day']
# not found in user utterance: summarize weatherquantifier ['what', 'is', 'the', 'current', 'temperature']
# not found in user utterance: temperature weatherprop ['when', 'was', 'the', 'warmest', 'point', 'of', 'the', 'day']
# not found in user utterance: max weatherquantifier ['when', 'was', 'the', 'warmest', 'point', 'of', 'the', 'day']
# not found in user utterance: max weatherquantifier ['whats', 'the', 'highest', 'temperature', 'for', 'the', 'week', 'in', 'des', 'moines', 'wa']
# not found in user utterance: moines, locationkeyphrase ['whats', 'the', 'highest', 'temperature', 'for', 'the', 'week', 'in', 'des', 'moines', 'wa']
# not found in user utterance: temperature weatherprop ['what', 'is', 'the', 'lowest']
# not found in user utterance: min weatherquantifier ['what', 'is', 'the', 'lowest']
# not found in user utterance: min weatherquantifier ['what', 'is', 'the', 'lowest', 'temperature', 'this', 'week', 'in', 'des', 'moines', 'wa']
# not found in user utterance: moines, locationkeyphrase ['what', 'is', 'the', 'lowest', 'temperature', 'this', 'week', 'in', 'des', 'moines', 'wa']
# not found in user utterance: output path ['i', 'need', 'it', 'later']
# ...
# not found in user utterance: start path ['can', 'you', 'make', 'it', 'last', 'from', 'friday', 'through', 'sunday', 'actually']
# not found in user utterance: output path ['can', 'you', 'make', 'it', 'last', 'from', 'friday', 'through', 'sunday', 'actually']
# not found in user utterance: november month ['add', 'my', 'holiday', 'vacation', 'from', 'nov', '21', 'to', 'dec', '2']
# not found in user utterance: december month ['add', 'my', 'holiday', 'vacation', 'from', 'nov', '21', 'to', 'dec', '2']
# not found in user utterance: summarize weatherquantifier ['thank', 'you', 'what', 'temperature', 'will', 'it', 'be', 'at', 'the', 'event']
# not found in user utterance: output path ['it', 'should', 'start', 'at', '9', '00am']
# not found in user utterance: output path ['im', 'going', 'to', 'workout', 'for', 'an', 'hour']
# not found in user utterance: appointment string ["when's", 'my', 'next', 'cat', 'vet', 'appoinment']
# not found in user utterance: [] list[path] ['move', 'the', 'first', 'event', 'to', 'sunday']
# not found in user utterance: frank personname ["i'd", 'like', 'for', 'a', 'quick', 'talk', 'with', "frank's", 'manager', 'to', 'be', 'scheduled', 'for', 'tomorrow']
# not found in user utterance: frank personname ['delete', 'quick', 'talk', 'with', "frank's", 'manager']
# not found in user utterance: output path ['yes', 'but', 'make', 'the', 'end', 'time', '3pm']
# not found in user utterance: temperature weatherprop ['what', 'is', 'the']
# not found in user utterance: summarize weatherquantifier ['what', 'is', 'the']
# not found in user utterance: output path ['can', 'you', 'also', 'add', 'that', 'the', 'meeting', 'is', 'at', 'townhouse', 'gate', 'mall']
# not found in user utterance: #44 string ['hello', 'please', 'add', 'event', 'an', 'evening', 'with', '44', 'start', 'time', 'is', '7', 'pm', 'on', 'tuesday', 'april']
# not found in user utterance: #44 string ['change', 'event', 'title', 'to', 'an', 'evening', 'with', '44']
# not found in user utterance: output path ['yes', 'please', 'add', 'monica', 'to', 'that', 'event', 'this', 'fall']
# not found in user utterance: output path ['anything', 'after', '5']
# not found in user utterance: output path ['invite', 'and', 'set', 'the', 'location', 'for', 'the', 'cemetery']
# not found in user utterance: output path ['bowser', 'is', 'coming', 'too', 'but', 'the', 'location', 'is', 'now', 'at', 'the', 'pet']
# not found in user utterance: output path ['change', 'it', 'to', "chili's", 'and', 'invite', 'john']
# not found in user utterance: & locationkeyphrase ['also', 'please', 'change', 'the', 'event', 'at', "howard's", 'bar', 'grill', 'to', 'be', 'not', 'on', 'the', 'weekend']
# not found in user utterance: output path ['can', 'you', 'change', 'that', 'to', 'the', '23rd', 'at', '5', 'pm', 'for', 'an', 'hour']
# not found in user utterance: output path ['change', 'the', 'meeting', 'to', 'the', 'next', 'day', 'instead']
# not found in user utterance: output path ['can', 'you', 'make', 'it', 'a', 'bit', 'earlier', 'in', 'the', 'day']
# not found in user utterance: [] list[path] ['can', 'you', 'make', 'it', 'a', 'bit', 'earlier', 'in', 'the', 'day']
# not found in user utterance: start path ['can', 'you', 'make', 'it', 'a', 'bit', 'earlier', 'in', 'the', 'day']
# not found in user utterance: [] list[path] ['i', 'would', 'like', 'to', 'move', 'that', 'staff', 'meeting', 'to', 'an', 'earlier', 'time', 'if', 'one', 'is', 'available']
# not found in user utterance: start path ['i', 'would', 'like', 'to', 'move', 'that', 'staff', 'meeting', 'to', 'an', 'earlier', 'time', 'if', 'one', 'is', 'available']
# not found in user utterance: output path ['make', 'it', '15', 'minutes', 'longer']
# not found in user utterance: output path ['can', 'you', 'add', 'harry', 'potter']
# not found in user utterance: output path ['extend', 'it', 'by', '30', 'minutes']
# not found in user utterance: d&d string ['good', 'did', 'my', 'friends', 'tentatively', 'accept', 'the', 'd', 'd', 'night', 'for', 'this', 'saturday']
# not found in user utterance: tentativelyaccepted responsestatustype ['good', 'did', 'my', 'friends', 'tentatively', 'accept', 'the', 'd', 'd', 'night', 'for', 'this', 'saturday']
# not found in user utterance: d&d string ['who', 'is', 'not', 'making', 'it', 'to', 'the', 'd', 'd', 'night', 'on', 'this', 'saturday']
# not found in user utterance: declined responsestatustype ['who', 'is', 'not', 'making', 'it', 'to', 'the', 'd', 'd', 'night', 'on', 'this', 'saturday']
# not found in user utterance: output path ['what', 'about', 'boss', 'meeting']
# not found in user utterance: none responsestatustype ['has', 'anybody', 'not', 'responded', 'to', 'that']
# not found in user utterance: output path ['make', 'that', 'from', '1', 'to', '2pm']
# not found in user utterance: [] list[path] ['can', 'you', 'change', 'that', 'to', 'start', 'at', '7', 'pm']
# not found in user utterance: output path ['what', 'about', 'tomorrow', 'afternoon']
# not found in user utterance: true boolean ['when', 'is', 'my', '1', '1', 'with', 'kim']
# not found in user utterance: true boolean ['when', 'is', 'my', '1', '1', 'with', 'matt', 'scheduled']
# not found in user utterance: [] list[path] ['move', 'the', 'fourth', 'one', 'to', 'next', 'week']
# not found in user utterance: dr. personname ['can', 'you', 'tell', 'me', 'when', 'my', 'appointment', 'with', 'dr', 'lane', 'is']
# not found in user utterance: accepted responsestatustype ['is', 'emily', 'going', 'to', 'that']
# not found in user utterance: output path ['yes', 'but', 'from', '5pm', 'to', '10', 'pm']
# not found in user utterance: output path ['make', 'it', 'a', 'few', 'days', 'later']
# not found in user utterance: declined responsestatustype ['can', 'you', 'decline', 'my', 'team', 'meeting', 'in', 'march', 'tell', 'tim', 'my', 'daughter', 'has', 'a', 'recital']
# not found in user utterance: declined responsestatustype ['yes', 'also', 'can', 'you', 'decline', 'meeting', 'to', 'cellphone', 'company', 'on', 'march', '4']
# not found in user utterance: declined responsestatustype ['okay', 'perfect', 'and', 'thank', 'you', 'for', 'that', 'can', 'you', 'please', 'decline', 'team', '2', 'meeting', 'too']
# not found in user utterance: output path ['what', 'about', 'thursday']
# not found in user utterance: familyfriendly placefeature ['is', "shae's", 'tavern', 'in', 'reno', 'family', 'friendly', 'in', 'your', 'opinion']
# not found in user utterance: familyfriendly placefeature ['is', 'kung', 'ho', 'chinese', 'restaurant', 'in', 'bellevue', 'family', 'friendly']
# not found in user utterance: kung-ho locationkeyphrase ['is', 'kung', 'ho', 'chinese', 'restaurant', 'in', 'bellevue', 'family', 'friendly']
# not found in user utterance: familyfriendly placefeature ['is', 'monsoon', 'bellevue', 'in', 'bellevue', 'family', 'friendly']
# not found in user utterance: output path ['yes', 'that', 'is', 'much', 'better', 'add', 'location', 'as', 'middle', 'school', 'field', 'thanks']
# not found in user utterance: output path ['make', 'it', '1', 'hour', 'longer']
# not found in user utterance: amy personname ['where', 'is', "amy's", 'contact', 'indo']
# not found in user utterance: output path ['great', 'also', 'invite', 'nick', 'to', 'the', 'meeting', 'as', 'well']
# not found in user utterance: outofoffice showasstatus ['then', 'make', 'me', 'out', 'of', 'office', 'until', '1', 'pm']
# not found in user utterance: [] list[path] ['move', 'the', 'fourth', 'event', 'to', '4', 'pm']
# not found in user utterance: output path ['and', 'what', 'about', 'monday']
# not found in user utterance: output path ['any', 'sales', 'meetings']
# not found in user utterance: output path ['change', 'day', 'to', 'april', '27']
# not found in user utterance: output path ['yes', 'and', 'also', 'set', 'location', 'to', 'halloween', 'town']
# not found in user utterance: output path ['add', 'this', 'for', 'next', 'year']
# not found in user utterance: cinema string ['sc']
# not found in user utterance: output path ['no', 'can', 'i', 'have', 'it', 'be', 'on', 'wednesday', 'at', '3pm']
# not found in user utterance: output path ['no', 'i', 'need', 'it', 'to', 'be', 'around', 'noon', 'time']
# not found in user utterance: output path ['neither', 'do', 'i', 'need', 'at', 'least', 'an', 'hour']
# not found in user utterance: output path ['extend', 'the', 'team', 'meeting', 'for', 'the', 'one', 'hour', 'more']
# not found in user utterance: workingelsewhere showasstatus ['put', 'me', 'as', 'working', 'else', 'where', 'from', '11', '00', 'am', 'to', '3', '30', 'pm', 'friday']
# not found in user utterance: output path ['can', 'you', 'add', 'michael', 'and', 'kevin', 'to', 'this', 'please']
# not found in user utterance: temperature weatherprop ['tonite', 'low']
# not found in user utterance: min weatherquantifier ['tonite', 'low']
# not found in user utterance: output path ['good', 'but', 'i', 'think', 'it', 'needs', 'to', 'be', 'an', 'hour', 'long']
# not found in user utterance: output path ['lets', 'do', '2pm']
# not found in user utterance: output path ['ok', 'make', 'it', 'for', '1p', 'm']
# not found in user utterance: output path ['i', 'need', 'an', 'hour']
# not found in user utterance: accepted responsestatustype ['can', 'you', 'accept', 'the', 'fishing', 'event', 'on', 'sunday', "don't", 'send', 'a', 'comment']
# not found in user utterance: accepted responsestatustype ['can', 'you', 'accept', 'the', 'madden', '20', 'event', 'please']
# not found in user utterance: accepted responsestatustype ['yep', 'can', 'you', 'also', 'accept', 'the', 'invitation', 'to', 'speak', 'to', 'my', 'psychologist']
# not found in user utterance: output path ['no', 'sorry', 'i', 'ment', 'to', 'say', '4', 'hours']
# not found in user utterance: rainprecipprobability weatherprop ['what', 'is', 'the', 'rain', 'forecast', 'here', 'for', 'today']
# not found in user utterance: summarize weatherquantifier ['what', 'is', 'the', 'rain', 'forecast', 'here', 'for', 'today']
# not found in user utterance: output path ['how', 'about', 'an', 'hour', 'earlier', 'than', 'that']
# not found in user utterance: [] list[path] ['how', 'about', 'an', 'hour', 'earlier', 'than', 'that']
# not found in user utterance: start path ['how', 'about', 'an', 'hour', 'earlier', 'than', 'that']
# not found in user utterance: output path ['yes', 'but', 'willy', "won't", 'be', 'there']
# not found in user utterance: output path ['yes', 'actually', 'change', 'of', 'plans', 'please', 'readd', 'willy']
# not found in user utterance: schoffel personname ['thanks', 'get', 'me', 'dan', "schoffel's", 'email', 'address']
# not found in user utterance: tim personname ['what', 'is', "tim's", 'phone', 'number']
# not found in user utterance: carla personname ['what', 'time', 'on', 'thursday', 'am', 'i', 'having', 'lunch', 'with', "carla's", 'manager']
# not found in user utterance: carla personname ['add', 'a', 'meeting', 'with', "carla's", 'manager', 'today', 'at', '3', '00', 'pm']
# not found in user utterance: price path ['which', 'one', 'higher', 'prices']
# not found in user utterance: tuesday dayofweek ['add', 'event', 'for', 'tueday', 'to', 'see', 'the', 'vet', 'around', '11am']
# not found in user utterance: output path ['no', 'please', 'schedule', 'the', 'hike', 'for', '2', '30', 'pm']
# not found in user utterance: [] list[path] ['and', 'the', 'second', 'event']
# not found in user utterance: clinton personname ['i', 'would', 'like', 'you', 'to', 'find', 'bill', "clinton's", 'email', 'address', 'please']
# not found in user utterance: rachel personname ['make', 'an', 'appointment', 'with', 'my', "rachel's", 'boss', 'at', 'today', '6pm']
# not found in user utterance: temperature weatherprop ['show', 'me', 'weather', 'for', 'friday', 'in', 'celsius']
# not found in user utterance: summarize weatherquantifier ['show', 'me', 'weather', 'for', 'friday', 'in', 'celsius']
# not found in user utterance: output path ['what', 'about', 'the', 'length', 'of', 'the', 'ball', 'game', 'tomorrow']
# not found in user utterance: output path ['can', 'you', 'please', 'add', 'that', 'becky', 'and', 'karen', 'will', 'be', 'in', 'attendance']
# not found in user utterance: d&d string ['cool', 'and', 'when', 'is', 'the', 'd', 'd', 'session', '0']
# not found in user utterance: meet-up string ['both', 'look', 'good', 'to', 'me', 'and', 'can', 'we', 'make', 'a', 'coffee', 'meet', 'up', 'with', 'kim', 'early', 'on', 'the', '10th']
# not found in user utterance: [] list[path] ['do', 'you', 'know', 'when', 'my', 'second', 'meeting', 'with', 'taylor', 'is']
# not found in user utterance: output path ['thank', 'you', 'but', 'i', 'need', 'it', 'for', 'next', 'friday', 'the', '18th', 'from', '8pm', '11', '30pm']
# not found in user utterance: output path ['no', 'what', 'about', 'december', '9th']
# not found in user utterance: output path ['could', 'you', 'try', 'for', 'next', 'month']
# not found in user utterance: output path ['add', 'jan', 'to', 'them']
# not found in user utterance: output path ['have', 'the', 'meeting', 'with', 'jon', 'and', 'jan', 'start', 'at', '10', '00', 'am', 'please']
# not found in user utterance: output path ['no', 'it', 'should', 'be', 'an', 'hour', 'long']
# not found in user utterance: rainprecipprobability weatherprop ['is', 'it', 'more', 'likely', 'to', 'rain', 'tomorrow', 'or', 'saturday']
# not found in user utterance: summarize weatherquantifier ['is', 'it', 'more', 'likely', 'to', 'rain', 'tomorrow', 'or', 'saturday']
# not found in user utterance: rainprecipprobability weatherprop ['is', 'it', 'more', 'likely', 'to', 'rain', 'tomorrow', 'or', 'saturday']
# not found in user utterance: summarize weatherquantifier ['is', 'it', 'more', 'likely', 'to', 'rain', 'tomorrow', 'or', 'saturday']
# not found in user utterance: output path ['thanks', 'change', 'it', 'to', 'be', 'an', 'hour', 'long', 'lunch', 'please']
# not found in user utterance: output path ['actually', 'move', 'it', 'to', '3', 'pm']
# not found in user utterance: output path ['no', 'move', 'it', 'to', '1pm']
# not found in user utterance: output path ['no', 'make', 'it', '1230']
# not found in user utterance: output path ['make', 'it', 'dinner']
# not found in user utterance: output path ['make', 'it', '8pm']
# not found in user utterance: tentativelyaccepted responsestatustype ['who', 'has', 'not', 'tentatively', 'accepted', 'wedding', 'plans']
# not found in user utterance: output path ['9pm', 'is', 'better']
# not found in user utterance: output path ['make', 'it', '10']
# not found in user utterance: output path ['have', 'this', 'last', 'until', '11', 'please']
# not found in user utterance: in-laws string ['i', 'would', 'like', 'to', 'schedule', 'a', 'visit', 'from', 'my', 'in', 'laws', 'next', 'thursday', 'through', 'the', 'following', 'monday']
# not found in user utterance: output path ['change', 'it', 'to', 'just', '7', 'days']
# not found in user utterance: [] list[path] ['change', 'it', 'to', 'just', '7', 'days']
# not found in user utterance: start path ['change', 'it', 'to', 'just', '7', 'days']
# not found in user utterance: output path ['it', 'for', 'four', 'days', 'please']
# not found in user utterance: [] list[path] ['it', 'for', 'four', 'days', 'please']
# not found in user utterance: start path ['it', 'for', 'four', 'days', 'please']
# not found in user utterance: output path ['oops', 'i', 'meant', 'the', 'one', 'after', 'that']
# not found in user utterance: true boolean ['so', 'am', 'i', 'free', 'next', 'week']
# not found in user utterance: output path ['i', 'meant', 'to', 'ask', 'when', 'i', 'am', 'free', 'tomorrow', 'not', 'next', 'week', 'thank', 'you']
# not found in user utterance: false boolean ['good', 'now', 'tell', 'is', 'kim', 'free', 'this', 'week']
# not found in user utterance: output path ['what', 'about', 'in', 'the', 'next', 'ten', 'days']
# not found in user utterance: output path ['what', 'about', 'my', 'events', 'on', 'sunday']
# not found in user utterance: in-n-out locationkeyphrase ['does', 'in', 'n', 'out', 'in', 'carson', 'city', 'have', 'takeout']
# not found in user utterance: nine-o locationkeyphrase ['does', 'the', 'nine', 'o', 'have', 'takeout']
# not found in user utterance: accepted responsestatustype ['who', 'went', 'with', 'me']

# %%
# example: tokens generated from a message
print("message:",train[0]["turns"][0]["user_utterance"]["original_text"])
print("tokens:",train[0]["turns"][0]["user_utterance"]["tokens2"])
print("readable tokens:",train[0]["turns"][0]["user_utterance"]["tokens2_readable"])
print("lispress tokens:",valid[0]["turns"][0]["lispress_tokens"])
print("lispress tokens readable:",valid[0]["turns"][2]["lispress_tokens_readable"])

print("lispress tokens with variables readable:",train_params[1]["turns"][0]["lispress_tokens_readable"])
print("lispress tokens with variables readable:",train_params[1]["turns"][0]["lispress_tokens_variable_readable"])

print("lispress tokens with variables readable:",train_params[1]["turns"][0]["user_utterance"]["tokens2_readable"])
print("lispress tokens with variables readable:",train_params[0]["turns"][0]["user_utterance"]["tokens2_variable_readable"])
# Out:
# message: what date is tomorrow?
# tokens: [18, 101, 12, 22]
# readable tokens: ['what', 'date', 'is', 'tomorrow']
# lispress tokens: [5, 1, 7, 8, 1, 29, 12, 1, 30, 10, 1, 9, 34, 1, 62, 1, 40, 33, 1, 14, 11, 1, 17, 1, 21, 1, 27, 10, 1, 25, 2, 26, 4, 1, 28, 3, 550, 3, 2, 2, 2, 2, 2, 2, 1, 40, 33, 1, 14, 11, 1, 17, 1, 21, 1, 27, 10, 1, 25, 2, 26, 4, 1, 28, 3, 191, 3, 2, 2, 2, 2, 2, 2, 2, 78, 1, 13, 1, 89, 4, 1, 15, 58, 2, 2, 2, 74, 1, 13, 4, 1, 59, 3, 211, 423, 1095, 3, 2, 2, 18, 1, 13, 1, 45, 16, 1, 44, 41, 4, 1, 38, 3, 122, 3, 2, 2, 22, 1, 42, 32, 4, 1, 15, 99, 2, 2, 2, 2, 19, 1, 13, 4, 1, 20, 3, 500, 3, 2, 2, 2, 2, 2, 2, 6]
# lispress tokens readable: ['<bos>', '(', 'yield', ':output', '(', 'createcommiteventwrapper', ':event', '(', 'createpreflighteventwrapper', ':constraint', '(', 'constraint[event]', ':attendees', '(', 'andconstraint', '(', 'andconstraint', '(', 'attendeelisthasrecipient', ':recipient', '(', 'execute', ':intension', '(', 'refer', '(', 'extensionconstraint', '(', 'recipientwithnamelike', ':constraint', '(', 'constraint[recipient]', ')', ':name', '#', '(', 'personname', '"', 'dennis', '"', ')', ')', ')', ')', ')', ')', '(', 'attendeelisthasrecipient', ':recipient', '(', 'execute', ':intension', '(', 'refer', '(', 'extensionconstraint', '(', 'recipientwithnamelike', ':constraint', '(', 'constraint[recipient]', ')', ':name', '#', '(', 'personname', '"', 'gabriel', '"', ')', ')', ')', ')', ')', ')', ')', '(', 'attendeelisthasrecipient', ':recipient', '(', 'execute', ':intension', '(', 'refer', '(', 'extensionconstraint', '(', 'recipientwithnamelike', ':constraint', '(', 'constraint[recipient]', ')', ':name', '#', '(', 'personname', '"', 'max', '"', ')', ')', ')', ')', ')', ')', ')', ':location', '(', '?=', '#', '(', 'locationkeyphrase', '"', "chili's", 'on', '15th', 'street', '"', ')', ')', ':start', '(', '?=', '(', 'nexttime', ':time', '(', 'hourminutepm', ':hours', '#', '(', 'number', '12', ')', ':minutes', '#', '(', 'number', '15', ')', ')', ')', ')', ':subject', '(', '?=', '#', '(', 'string', '"', 'lunch', 'meeting', '"', ')', ')', ')', ')', ')', ')', '<eos>']
# lispress tokens with variables readable: ['<bos>', '(', 'yield', ':output', '(', ':start', '(', 'singleton', '(', ':results', '(', 'findeventwrapperwithdefaults', ':constraint', '(', 'eventondate', ':date', '(', 'nextdow', ':dow', '#', '(', 'dayofweek', '"', 'friday', '"', ')', ')', ':event', '(', 'constraint[event]', ':attendees', '(', 'attendeelisthasrecipientconstraint', ':recipientconstraint', '(', 'recipientwithnamelike', ':constraint', '(', 'constraint[recipient]', ')', ':name', '#', '(', 'personname', '"', 'jerri', 'skinner', '"', ')', ')', ')', ')', ')', ')', ')', ')', ')', ')', '<eos>']
# lispress tokens with variables readable: ['<bos>', '(', 'yield', ':output', '(', ':start', '(', 'singleton', '(', ':results', '(', 'findeventwrapperwithdefaults', ':constraint', '(', 'eventondate', ':date', '(', 'nextdow', ':dow', '#', '(', 'dayofweek', '"', '<dayofweek0>', '"', ')', ')', ':event', '(', 'constraint[event]', ':attendees', '(', 'attendeelisthasrecipientconstraint', ':recipientconstraint', '(', 'recipientwithnamelike', ':constraint', '(', 'constraint[recipient]', ')', ':name', '#', '(', 'personname', '"', '<personname0>', 'skinner', '"', ')', ')', ')', ')', ')', ')', ')', ')', ')', ')', '<eos>']
# lispress tokens with variables readable: ['what', 'time', 'is', 'my', 'appointment', 'with', 'jerri', 'skinner', 'on', 'friday']
# lispress tokens with variables readable: ['what', 'date', 'is', 'tomorrow']

# %%
# user tokenizer on the parameterized input
user_tokenizer_params = Tokenizer()
dialogue_sent = [turn['user_utterance']['tokens2_variable_readable'] for dialog in train_params for turn in dialog['turns'] ]
user_tokenizer_params.fit_on_texts(dialogue_sent)
# lispress tokenizer on the parameterized programs
lispress_tokenizer_params = Tokenizer()
dialogue_sent_lispress_params = [turn['lispress_tokens_variable_readable'] for dialog in train_params for turn in dialog['turns']]
lispress_tokenizer_params.fit_on_texts(dialogue_sent_lispress_params)

# %%
lispress_tokenizer_params.word_index["<bos>"]
# Out:
# 5

# %%
def tokenizer_with_params(dataset,user_tokenizer,lispress_tokenizer):
    for dialog in dataset:
        for turn in dialog['turns']:
            turn["user_utterance"].update({"tokens2_variable":[user_tokenizer.word_index[word] if word in user_tokenizer.word_index else 0 for word in turn["user_utterance"]["tokens2_variable_readable"]]})
            turn.update({"lispress_tokens_variable":[lispress_tokenizer.word_index[word] if word in lispress_tokenizer.word_index else 0 for word in turn["lispress_tokens_variable_readable"]]})
    tokenized_train = [[ turn['user_utterance']['tokens2_variable'] for turn in dialog['turns'] ]for dialog in dataset]
    tokenized_lispress = [[ turn['lispress_tokens_variable'] for turn in dialog['turns'] ]for dialog in dataset]
    return tokenized_train,tokenized_lispress

# %%
train_tokenized,train_tokenized_lispress = tokenizer_with_params(train_params,user_tokenizer_params,lispress_tokenizer_params)
valid_tokenized,valid_tokenized_lispress = tokenizer_with_params(valid_params,user_tokenizer_params,lispress_tokenizer_params)

# %%
def flatten_nested_list(list0):
    """
    Flatten the nested list's elements
    Example:
    [[1,2],[3]] => [1,2,3]
    """
    return [element for nested in list0 for element in nested ]

# %% [markdown]
# ### Create train,validation,test data

# %%
if RUN_MODE == RUN_FULLMODE:

    MAX_TRAIN_DATA=-1 #how many train data will be used from the training set
    MAX_VALID_DATA=-100 # the last 99 elements of the validation data will be used as test data
    MAX_TEST_DATA=99

elif RUN_MODE == RUN_TESTMODE:
    MAX_TRAIN_DATA=20000 #limited training mode with 10000 data
    MAX_VALID_DATA=2000 # the last 99 elements of the validation data will be used as test data
    MAX_TEST_DATA=99

# %%
from copy import deepcopy
def create_previous_program_input(data):
    """
    from each dealogue -> remove the last element, and add a 0 to the beginning
    """
    data_tmp = deepcopy(data)
    for seqs in data_tmp:
        del seqs[-1]
        seqs.insert(0,[0])
    return data_tmp

# %%
# the user messages
train_data = flatten_nested_list(train_tokenized)[:MAX_TRAIN_DATA]
valid_data = flatten_nested_list(valid_tokenized)[:MAX_VALID_DATA]
test_data = flatten_nested_list(valid_tokenized)[MAX_VALID_DATA:MAX_VALID_DATA+MAX_TEST_DATA]

#the program stored in the last dialogue turn -> currently they are not taken into account
train_data_di = flatten_nested_list(create_previous_program_input(train_tokenized_lispress))[:MAX_TRAIN_DATA]
valid_data_di = flatten_nested_list(create_previous_program_input(valid_tokenized_lispress))[:MAX_VALID_DATA]
test_data_di = flatten_nested_list(create_previous_program_input(valid_tokenized_lispress))[MAX_VALID_DATA:MAX_VALID_DATA+MAX_TEST_DATA]

#the current program
train_data_y = flatten_nested_list(train_tokenized_lispress)[:MAX_TRAIN_DATA]
valid_data_y = flatten_nested_list(valid_tokenized_lispress)[:MAX_VALID_DATA]
test_data_y = flatten_nested_list(valid_tokenized_lispress)[MAX_VALID_DATA:MAX_VALID_DATA+MAX_TEST_DATA]

# %%
# the length of the decoder input and output
MAX_LEN_DEC=max([len(i) for i in train_data_y])
print(MAX_LEN_DEC)

MAX_LEN_ENC=max([len(i) for i in train_data])
print(MAX_LEN_ENC)
# Out:
# 510
# 98

# %%
# generate encoder input, decoder input and decoder target sequences
def generate_dataset(encoder_input,previous_program,current_program):
    """
    Creates the encoder input, decoder input and decoder output.
    For each target program create len(program)-1 training data:
    #   |Encoder input | Decoder input | Decoder output
    1.  |input sequence 1 | current program 1 first token | current program 1 second token
    2.  |input sequence 1 | current program 1 first two tokens | current program 1 2. and 3. tokens
    ...
    n.  |input sequence 1 | current program 1 n-MAX_LEN_DEC-1 -> n-1 tokens | current program 1 n-MAX_LEN_DEC -> n tokens
    n+1.|input sequence 2 | ...
    
    Parameters:
    encoder_input (list): list of input sequences
    previous_program (list): list of previous programs
    current_program (list): list of current programs (target)

    Returns:
    data: generated encoder input
    data_di: generated decoder input
    data_y: generated decoder output
    """
    data,data_di,data_y = [],[],[]
    for i,sent in enumerate(current_program):
        data.append(encoder_input[i])
        data_di.append(current_program[i])
        data_y.append(current_program[i][1:])
    return data,data_di,data_y

# %%
train_data_new,train_data_new_di,train_data_new_y = None,None,None
valid_data_new,valid_data_new_di,valid_data_new_y = None,None,None
test_data_new,test_data_new_di,test_data_new_y = None,None,None

# %%
# generate the training data
train_data_new,train_data_new_di,train_data_new_y = generate_dataset(train_data,train_data_di,train_data_y)
valid_data_new,valid_data_new_di,valid_data_new_y = generate_dataset(valid_data,valid_data_di,valid_data_y)
test_data_new,test_data_new_di,test_data_new_y = generate_dataset(test_data,test_data_di,test_data_y)

# %%
train_data_new[:10]
# Out:
# [[22, 104, 16, 25],
#  [22, 51, 45, 1, 44, 16, 25],
#  [28, 150, 36],
#  [22, 43, 16, 10, 37, 9, 6, 422, 11, 14],
#  [18, 15, 30, 41, 37, 9, 6, 422, 8, 7, 39],
#  [4, 42, 20, 3, 70, 7, 89],
#  [48, 55],
#  [18, 15, 889, 2, 9, 6, 21, 188, 162],
#  [739, 1, 401, 145, 38, 2, 112, 21, 158, 6],
#  [30, 430, 122, 3932, 6, 2502, 503, 468, 393, 350]]

# %%
train_data_new_di[:1]
# Out:
# [[5, 1, 7, 8, 1, 64, 2, 2, 6]]

# %%
train_data_new_y[:1]
# Out:
# [[1, 7, 8, 1, 64, 2, 2, 6]]

# %% [markdown]
# ### Padding encoder and decoder inputs, and decoder output

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
MAX_LEN=MAX_LEN_ENC # length of the encoder input

# padding the encoder, and decoder inputs
# padding will be added to the end of the encoder input (if needed)
# padding will be added to the begining of the decoder inputs and outputs (if needed)

encoder_train = pad_sequences(train_data_new,maxlen=MAX_LEN_ENC,dtype="int32",padding='post', truncating='post')
decoder_train = pad_sequences(train_data_new_y,maxlen=MAX_LEN_DEC,dtype="int32",padding='post', truncating='post')
decoder_train_input = pad_sequences(train_data_new_di,maxlen=MAX_LEN_DEC,dtype="int32",padding='post', truncating='post')

encoder_valid = pad_sequences(valid_data_new,maxlen=MAX_LEN_ENC,dtype="int32",padding='post', truncating='post')
decoder_valid = pad_sequences(valid_data_new_y,maxlen=MAX_LEN_DEC,dtype="int32",padding='post', truncating='post')
decoder_valid_input = pad_sequences(valid_data_new_di,maxlen=MAX_LEN_DEC,dtype="int32",padding='post', truncating='post')

encoder_test = pad_sequences(test_data_new,maxlen=MAX_LEN_ENC,dtype="int32",padding='post', truncating='post')
decoder_test = pad_sequences(test_data_new_y,maxlen=MAX_LEN_DEC,dtype="int32",padding='post', truncating='post')
decoder_test_input = pad_sequences(test_data_new_di,maxlen=MAX_LEN_DEC,dtype="int32",padding='post', truncating='post')

# %% [markdown]
# ### Create embedding matrices for the embedding layers

# %%
import os
import numpy as np

# %%
# load the glove vector representations
GLOVE_DIR="glove"
embeddings_index = {}
with open(os.path.join(root_path,GLOVE_DIR,"glove.6B.100d.txt"),'rb') as f:
    for line in f.readlines():
        values = line.split()
        word = str(values[0],encoding="utf8")
        coefs = np.asanyarray(values[1:], dtype="float32")
        embeddings_index[word] = coefs

# %%
# create embedding matrix for the encoder
embedding_dimension = 100
DECODING_DEPTH = len(lispress_tokenizer.word_index)+1
embedding_matrix_encoder = np.zeros((len(tokenizer_user.word_index)+1,embedding_dimension))
for word, i in tokenizer_user.word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        embedding_matrix_encoder[i] = embedding_vector

# create embedding matrix for the decoder
embedding_matrix_decoder = np.zeros((DECODING_DEPTH,embedding_dimension))
for word, i in lispress_tokenizer.word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None and i < DECODING_DEPTH:
        embedding_matrix_decoder[i] = embedding_vector

# %%
def decoder_output_creater(decoder_input_data, num_samples, MAX_LEN, VOCAB_SIZE):  
    """
    Creates the one hot encoded version of the data
    """
    decoder_output_data = np.zeros((num_samples, MAX_LEN, VOCAB_SIZE), dtype="float32")

    for i, seqs in enumerate(decoder_input_data):
        for j, seq in enumerate(seqs):
            if j > 0 and seq < VOCAB_SIZE:
                decoder_output_data[i][j][seq] = 1.

    return decoder_output_data

# %% [markdown]
# ### Create seq2seq model
#
# Simple sequence to sequence model with LSTM encoder and decoder

# %%
from tensorflow.keras.layers import TimeDistributed
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.layers import Embedding,Dense,Activation,Concatenate,Bidirectional
from tensorflow.keras.layers import Input, LSTM, Dense

# %%
# Attention definition

from tensorflow.keras import backend as K
from tensorflow.keras.layers import Layer
from tensorflow.keras import initializers, regularizers, constraints

class Attention(Layer):
    def __init__(self, step_dim,
                 W_regularizer=None, b_regularizer=None,
                 W_constraint=None, b_constraint=None,
                 bias=True, **kwargs):
        self.supports_masking = True
        self.init = initializers.get('glorot_uniform')

        self.W_regularizer = regularizers.get(W_regularizer)
        self.b_regularizer = regularizers.get(b_regularizer)
        self.W_constraint = constraints.get(W_constraint)
        self.b_constraint = constraints.get(b_constraint)
        
        self.bias = bias
        self.step_dim = step_dim
        self.features_dim = 0
        super(Attention, self).__init__(**kwargs)

    def build(self, input_shape):
        assert len(input_shape) == 3
        self.W = self.add_weight(shape=(input_shape[-1],),
                                 name='{}_W'.format(self.name),
                                 initializer=self.init,
                                 regularizer=self.W_regularizer,
                                 constraint=self.W_constraint)
        self.features_dim = input_shape[-1]
        if self.bias:
            self.b = self.add_weight(shape=(input_shape[1],),
                                     name='{}_b'.format(self.name),
                                     initializer='zero',
                                     regularizer=self.b_regularizer,
                                     constraint=self.b_constraint)
        else:
            self.b = None
        self.built = True

    def compute_mask(self, input, input_mask=None):
        return None

    def call(self, x, mask=None):
        features_dim = self.features_dim
        step_dim = self.step_dim
        eij = K.reshape(K.dot(K.reshape(x, (-1, features_dim)), K.reshape(self.W, (features_dim, 1))), (-1, step_dim))
        if self.bias:
            eij += self.b
        eij = K.tanh(eij)
        a = K.exp(eij)
        if mask is not None:
            a *= K.cast(mask, K.floatx())
        a /= K.cast(K.sum(a, axis=1, keepdims=True) + K.epsilon(), K.floatx())
        a = K.expand_dims(a)
        weighted_input = x * a
        return weighted_input

    def compute_output_shape(self, input_shape):
        return input_shape[0], input_shape[1], input_shape[-1]

# %%
def create_lstm_model(hidden_dim=128):
    embedding_dimension=100

    #create encoder embedding layer
    encoder_inputs = Input(shape=(MAX_LEN_ENC, ),dtype="int32")
    encoder_embedding = Embedding(input_dim = num_encoder_tokens,
                                output_dim = embedding_dimension,
                                input_length = MAX_LEN_ENC,
                                weights = [embedding_matrix_encoder],
                              trainable = False)(encoder_inputs)
    #create encoder lstm layer
    encoder_LSTM = LSTM(hidden_dim, return_state=True)
    encoder_outputs, state_h, state_c = encoder_LSTM(encoder_embedding)

    #create decoder embedding layer
    decoder_inputs = Input(shape=(MAX_LEN_DEC, ),dtype="int32")
    decoder_embedding = Embedding(input_dim = DECODING_DEPTH,
                                output_dim = embedding_dimension,
                                input_length = MAX_LEN_DEC,
                                weights = [embedding_matrix_decoder],
                              trainable = False)(decoder_inputs)
    #create decoder LSTM layer using the encoder states
    decoder_LSTM = LSTM(hidden_dim, return_state=True, return_sequences=True)(decoder_embedding, initial_state=[state_h, state_c])

    if ATTENTION_LAYER:
      decoder_outputs = Attention(MAX_LEN_DEC)(decoder_LSTM[0])
    else:
      decoder_outputs, _, _ = decoder_LSTM

    #output time distributed dense layer with softmax activation
    outputs = TimeDistributed(Dense(DECODING_DEPTH, activation='softmax'))(decoder_outputs)
    model = Model([encoder_inputs, decoder_inputs], outputs)

    return model

def create_bilstm_model(hidden_dim=128):
    embedding_dimension=100

    #create encoder embedding layer
    encoder_inputs = Input(shape=(MAX_LEN_ENC, ),dtype="int32")
    encoder_embedding = Embedding(input_dim = num_encoder_tokens,
                                output_dim = embedding_dimension,
                                input_length = MAX_LEN_ENC,
                                weights = [embedding_matrix_encoder],
                              trainable = False)(encoder_inputs)
    
    encoder_LSTM = Bidirectional(LSTM(hidden_dim, return_state=True), merge_mode="concat")
    encoder_outputs, forward_h, forward_c, backward_c, backward_h = encoder_LSTM(encoder_embedding)
    state_h = Concatenate()([forward_h, backward_h])
    state_c = Concatenate()([forward_c, backward_c])
    encoder_states = [forward_h, forward_c, backward_h, backward_c]
    #create encoder lstm layer
    #encoder_LSTM = LSTM(hidden_dim, return_state=True)
    #encoder_outputs, state_h, state_c = encoder_LSTM(encoder_embedding)

    #create decoder embedding layer
    decoder_inputs = Input(shape=(MAX_LEN_DEC, ),dtype="int32")
    decoder_embedding = Embedding(input_dim = DECODING_DEPTH,
                                output_dim = embedding_dimension,
                                input_length = MAX_LEN_DEC,
                                weights = [embedding_matrix_decoder],
                              trainable = False)(decoder_inputs)
    decoder_LSTM_1 = Bidirectional(LSTM(hidden_dim, return_state=False, return_sequences=True), merge_mode="concat")(decoder_embedding, initial_state=encoder_states)
    decoder_LSTM_2 = Bidirectional(LSTM(hidden_dim, return_state=False, return_sequences=True), merge_mode="concat")(decoder_LSTM_1)
    #create decoder LSTM layer using the encoder states
    #decoder_LSTM = LSTM(hidden_dim, return_state=True, return_sequences=True)
    #decoder_outputs, _, _ = decoder_LSTM(decoder_embedding, initial_state=[state_h, state_c])

    if ATTENTION_LAYER:
      decoder_outputs = Attention(MAX_LEN_DEC)(decoder_LSTM_2)
    else:
      decoder_outputs = decoder_LSTM_2

    #output time distributed dense layer with softmax activation
    outputs = TimeDistributed(Dense(DECODING_DEPTH, activation='softmax'))(decoder_outputs)
    model = Model([encoder_inputs, decoder_inputs], outputs)

    return model

# %%
num_encoder_tokens = len(tokenizer_user.word_index)+1
num_decoder_tokens = len(lispress_tokenizer.word_index)+1

# %%
if MODEL_TYPE == MODEL_LSTM:
    model = create_lstm_model(HIDDEN_DIM)
elif MODEL_TYPE == MODEL_BILSTM:
    model = create_bilstm_model(HIDDEN_DIM)

# %%
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 98)]         0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 510)]        0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 98, 100)      1629700     input_1[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 510, 100)     1260700     input_2[0][0]
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   [(None, 256), (None, 234496      embedding[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 510, 256)     234496      embedding_1[0][0]
#                                                                  bidirectional[0][1]
#                                                                  bidirectional[0][2]
#                                                                  bidirectional[0][4]
#                                                                  bidirectional[0][3]
# __________________________________________________________________________________________________
# bidirectional_2 (Bidirectional) (None, 510, 256)     394240      bidirectional_1[0][0]
# __________________________________________________________________________________________________
# attention (Attention)           (None, 510, 256)     766         bidirectional_2[0][0]
# __________________________________________________________________________________________________
# time_distributed (TimeDistribut (None, 510, 12607)   3239999     attention[0][0]
# ==================================================================================================
# Total params: 6,994,397
# Trainable params: 4,103,997
# Non-trainable params: 2,890,400
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
import tensorflow as tf

# %%
plot_model(model,show_layer_names=True)

# %%
model.compile(optimizer="adam",loss="categorical_crossentropy",metrics=["accuracy"])

# %% [markdown]
# ## Training

# %%
# data generator for the training
class DataGenerator(tf.keras.utils.Sequence):
    def __init__(self, input, batch_size=32, num_classes=None, shuffle=False):
        self.batch_size = batch_size
        self.input = input
        self.indices = list(range(len(input[0])))
        self.num_classes = num_classes
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        return len(self.indices) // self.batch_size

    def __getitem__(self, index):
        index = self.index[index * self.batch_size:(index + 1) * self.batch_size]
        batch = [self.indices[k] for k in index]
        
        X, y = self.__get_data(batch)
        return X, y

    def on_epoch_end(self):
        self.index = np.arange(len(self.indices))
        if self.shuffle == True:
            np.random.shuffle(self.index)

    def __get_data(self, batch):
        #print(batch[0],batch[-1])
        encoder = np.array(self.input[0][batch[0]:batch[-1]+1])
        decoder = np.array(self.input[1][batch[0]:batch[-1]+1])
        X = [encoder,decoder]
        #print(X)
        y = decoder_output_creater(self.input[2][batch[0]:batch[-1]+1],len(batch),MAX_LEN_DEC,DECODING_DEPTH)

        return X, y

# %%
len(encoder_train)
# Out:
# 20000

# %%
batch_size = BATCH_SIZE

model.fit(DataGenerator([encoder_train,decoder_train_input,decoder_train],batch_size=batch_size),
         batch_size=batch_size,epochs=EPOCHS,validation_data=DataGenerator([encoder_valid,decoder_valid_input,decoder_valid],batch_size=batch_size))
# Out:
# 625/625 [==============================] - 494s 791ms/step - loss: 8.5845 - accuracy: 0.9241 - val_loss: 7.7398 - val_accuracy: 0.9227

# %%
if PERSIST_MODEL_AS is not None:
    model.save(os.path.join("models",PERSIST_MODEL_AS))

# %%
def extract_lispress_from_pred(pred,tokenizer):
    """
    Returns the lispress program and lispress token codes from the prediction
    """
    lines = []
    codes = []
    for p in pred:
        line = [tokenizer.index_word[np.argmax(vec)] if np.argmax(vec) > 0 else "UNKNOWN" for vec in p ]
        code = [np.argmax(vec) for vec in p ]
        #print(codes)
        lines.append(line)
        codes.append(code)
    return lines,codes

# %%
def make_prediction(sent,program,user_tokenizer,lispress_tokenizer,model,isText=True):
    """
    Makes prediction for a given sentence
    
    Method: the input of the encoder will be the given sentence in each turn; the decoder input will be first a <bos> token,
    we apply padding to shift the <bos> token to the end of the decoder input. Then we make a prediction, and concat the last token of the
    prediction to the previous decoder input. We repeat this until we gets an <eos> token or we reach the max length
    
    Parameters:
    sent (string|list): input code sequence or input text
    program: not used
    user_tokenizer
    lispress_tokenizer
    model
    isText (boolean): True if the input is text False else
    
    Returns the predicted lispress program (token codes)
    """
    if isText:
        seq = user_tokenizer.texts_to_sequences([sent])[0]
    else:
        seq = sent
    print("Question:", [user_tokenizer.index_word[code] if code in user_tokenizer.index_word else "unknown" for code in seq])
    decoder = ["<bos>"]
    length = 0
    MAX_LENGTH = 100
    decoder_seq = [lispress_tokenizer.word_index[word] for word in decoder]

    seq_pad = pad_sequences([seq],maxlen=MAX_LEN,dtype="int32",padding='post', truncating='post')[0]
    decoder_pad = pad_sequences([decoder_seq],maxlen=MAX_LEN_DEC,dtype="int32",padding='pre', truncating='pre')[0]

    line = [["asd"]]

    while length < MAX_LENGTH and line[0][-1] != '<eos>':
        pred = model.predict([np.array([seq_pad]),np.array([decoder_pad])])[0]
        line,code = extract_lispress_from_pred([pred],lispress_tokenizer)
        decoder_seq.append(code[0][-1])
        decoder_pad = pad_sequences([decoder_seq],maxlen=MAX_LEN_DEC,dtype="int32",padding='pre', truncating='pre')[0]
        length += 1

    print("Program:",[lispress_tokenizer.index_word[code0] if code0>0 else "UNKNOWN" for code0 in decoder_seq])  

    return decoder_seq

# %%
def make_prediction2(sent,program,user_tokenizer,lispress_tokenizer,model,isText=True):
    """
    Makes prediction for a given sentence
    
    Method: the input of the encoder will be the given sentence in each turn; the decoder input will be first a <bos> token,
    we apply padding to shift the <bos> token to the end of the decoder input. Then we make a prediction, and concat the last token of the
    prediction to the previous decoder input. We repeat this until we gets an <eos> token or we reach the max length
    
    Parameters:
    sent (string|list): input code sequence or input text
    program: not used
    user_tokenizer
    lispress_tokenizer
    model
    isText (boolean): True if the input is text False else
    
    Returns the predicted lispress program (token codes)
    """
    if isText:
        seq = user_tokenizer.texts_to_sequences([sent])[0]
    else:
        seq = sent
    print("Question:", [user_tokenizer.index_word[code] if code in user_tokenizer.index_word else "unknown" for code in seq])
    decoder = ["<bos>","(","yield",":output"]
    length = 4
    MAX_LENGTH = MAX_LEN_DEC
    decoder_seq = [lispress_tokenizer.word_index[word] for word in decoder]
    next_index = 3
    seq_pad = pad_sequences([seq],maxlen=MAX_LEN,dtype="int32",padding='post', truncating='post')[0]
    decoder_pad = pad_sequences([decoder_seq],maxlen=MAX_LEN_DEC,dtype="int32",padding='post', truncating='post')[0]

    line = [["asd","asd","asd","asd"]]
    last_token="asd"
    while length < MAX_LENGTH and last_token != '<eos>':
        #print(next_index)
        #print(length)
        pred = model.predict([np.array([seq_pad]),np.array([decoder_pad])])[0]
        line,code = extract_lispress_from_pred([pred],lispress_tokenizer)
        print(line[0])
        decoder_seq.append(code[0][next_index])
        last_token = line[0][next_index]
        #decoder_seq.append(code[0][-1])
        #print(decoder_seq)
        if code[0][next_index] == 0:
            break
        next_index+=1
        
        decoder_pad = pad_sequences([decoder_seq],maxlen=MAX_LEN_DEC,dtype="int32",padding='post', truncating='post')[0]
        length += 1
        #print(" ".join([lispress_tokenizer.index_word[code] for code in decoder_seq]))

    print("Program:",[lispress_tokenizer.index_word[code0] if code0>0 else "UNKNOWN" for code0 in decoder_seq])  

    return decoder_seq

# %%
from tensorflow.keras.models import load_model

# %%
# load a model trained on the first 1 million data (if you want to skip the training part)
#model = load_model('models/model20201121_newtokenizer_50-50-1M.h5')
#model.save("models/model20201125_parameterized_fulllength_e14.h5")

# %% [markdown]
# ## Evaluation

# %%
TP=0
ALL=0
for i,test in enumerate(test_data[:]):
    prediction = make_prediction2(test,[],user_tokenizer=user_tokenizer_params,lispress_tokenizer=lispress_tokenizer_params,model=model,isText=False)
    print("Expected:",[lispress_tokenizer_params.index_word[code] if code in lispress_tokenizer_params.index_word else "UNKNOWNCODE"  for code in test_data_y[i]])
    ALL+=1
    if len(prediction) == len(test_data_y[i]) and np.sum([ 0 if pred == expected else 1 for pred,expected in zip(prediction,test_data_y[i])] ) == 0:
        TP+=1
    print("Accuracy:",TP/ALL)

print("Accuracy:",TP/ALL)
# Out:
# Question: ['cancel', 'my', '<string0>', 'to', 'san', 'francisco', 'on', '<dayofweek0>']
# ['UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNO ...
# Program: ['<bos>', '(', 'yield', ':output', 'UNKNOWN']
# Expected: ['<bos>', '(', 'yield', ':output', '(', 'deletecommiteventwrapper', ':event', '(', 'deletepreflighteventwrapper', ':id', '(', ':id', '(', 'singleton', '(', ':results', '(', 'findeventwrapperwithdefaults', ':constraint', '(', 'eventondate', ':date', '(', 'nextdow', ':dow', '#', '(', 'dayofweek', '"', '<dayofweek0>', '"', ')', ')', ':event', '(', 'constraint[event]', ':subject', '(', '?~=', '#', '(', 'string', '"', '<string0>', 'to', 'san', 'francisco', '"', ')', ')', ')', ')', ')', ')', ')', ')', ')', ')', ')', '<eos>']
# Accuracy: 0.0
# Question: ['make', 'the', '<string0>', 'to', 'san', 'francisco', 'two', 'days', 'instead']
# ['UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNO ...
# Program: ['<bos>', '(', 'yield', ':output', 'UNKNOWN']
# Expected: ['<bos>', '(', 'let', '(', 'x0', '(', 'singleton', '(', ':results', '(', 'findeventwrapperwithdefaults', ':constraint', '(', 'constraint[event]', ':subject', '(', '?~=', '#', '(', 'string', '"', '<string0>', 'to', 'san', 'francisco', '"', ')', ')', ')', ')', ')', ')', ')', '(', 'yield', ':output', '(', 'updatecommiteventwrapper', ':event', '(', 'updatepreflighteventwrapper', ':id', '(', ':id', 'x0', ')', ':update', '(', 'eventalldaystartingdateforperiod', ':event', '(', 'constraint[event]', ')', ':period', '(', 'todays', '#', '(', 'number', '2', ')', ')', ':startdate', '(', ':date', '(', ':start', 'x0', ')', ')', ')', ')', ')', ')', ')', '<eos>']
# Accuracy: 0.0
# Question: ['yep', 'looks', 'great']
# ['UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNO ...
# Program: ['<bos>', '(', 'yield', ':output', 'UNKNOWN']
# Expected: ['<bos>', '(', 'yield', ':output', '(', 'execute', ':intension', '(', 'confirmandreturnaction', ')', ')', ')', '<eos>']
# Accuracy: 0.0
# Question: ['when', 'do', 'i', 'next', 'have', 'an', 'all', 'day', 'event', 'with', '<personname0>']
# ['UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNO ...
# Program: ['<bos>', '(', 'yield', ':output', 'UNKNOWN']
# Expected: ['<bos>', '(', 'yield', ':output', '(', ':start', '(', 'findnumnextevent', ':constraint', '(', 'constraint[event]', ':attendees', '(', 'attendeelisthasrecipientconstraint', ':recipientconstraint', '(', 'recipientwithnamelike', ':constraint', '(', 'constraint[recipient]', ')', ':name', '#', '(', 'personname', '"', '<personname0>', '"', ')', ')', ')', ':isallday', '(', '?=', '#', '(', 'boolean', 'true', ')', ')', ')', ':number', '#', '(', 'number', '1', ')', ')', ')', ')', '<eos>']
# Accuracy: 0.0
# Question: ['can', 'you', 'add', '<string0>', 'up', 'my', 'kids', 'from', 'school', 'on', '<dayofweek0>']
# ['UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNO ...
# Program: ['<bos>', '(', 'yield', ':output', 'UNKNOWN']
# Expected: ['<bos>', '(', 'yield', ':output', '(', 'createcommiteventwrapper', ':event', '(', 'createpreflighteventwrapper', ':constraint', '(', 'constraint[event]', ':start', '(', 'constraint[datetime]', ':date', '(', '?=', '(', 'nextdow', ':dow', '#', '(', 'dayofweek', '"', '<dayofweek0>', '"', ')', ')', ')', ')', ':subject', '(', '?=', '#', '(', 'string', '"', '<string0>', 'up', 'my', 'kids', 'from', 'school', '"', ')', ')', ')', ')', ')', ')', '<eos>']
# Accuracy: 0.0
# Question: ['i', 'need', 'to', 'add', 'an', 'event', 'to', 'my', 'calendar']
# ['UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNO ...
# Program: ['<bos>', '(', 'yield', ':output', 'UNKNOWN']
# Expected: ['<bos>', '(', 'yield', ':output', '(', 'createcommiteventwrapper', ':event', '(', 'createpreflighteventwrapper', ':constraint', '(', 'constraint[event]', ')', ')', ')', ')', '<eos>']
# Accuracy: 0.0
# Question: ['yes']
# ['UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNO ...
# Program: ['<bos>', '(', 'yield', ':output', 'UNKNOWN']
# Expected: ['<bos>', '(', 'yield', ':output', '(', 'execute', ':intension', '(', 'choosecreateeventfromconstraint', ':constraint', '(', 'constraint[event]', ')', ':intension', '(', 'refer', '(', 'actionintensionconstraint', ')', ')', ')', ')', ')', '<eos>']
# Accuracy: 0.0
# Question: ['can', 'you', 'add', 'an', 'event']
# ['UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNO ...
# Program: ['<bos>', '(', 'yield', ':output', 'UNKNOWN']
# Expected: ['<bos>', '(', 'yield', ':output', '(', 'createcommiteventwrapper', ':event', '(', 'createpreflighteventwrapper', ':constraint', '(', 'constraint[event]', ')', ')', ')', ')', '<eos>']
# Accuracy: 0.0
# Question: ['re', 'arrange', 'the', 'meeting', 'at', 'tomorrow', '<number0>', 'pm']
# ['UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNO ...
# Program: ['<bos>', '(', 'yield', ':output', 'UNKNOWN']
# Expected: ['<bos>', '(', 'yield', ':output', '(', 'updatecommiteventwrapper', ':event', '(', 'updatepreflighteventwrapper', ':id', '(', ':id', '(', 'singleton', '(', ':results', '(', 'findeventwrapperwithdefaults', ':constraint', '(', 'constraint[event]', ')', ')', ')', ')', ')', ':update', '(', 'constraint[event]', ':start', '(', '?=', '(', 'dateattimewithdefaults', ':date', '(', 'tomorrow', ')', ':time', '(', 'numberpm', ':number', '#', '(', 'number', '<number0>', ')', ')', ')', ')', ')', ')', ')', ')', '<eos>']
# Accuracy: 0.0
# Question: ['do', 'i', 'have', 'a', 'meeting', 'with', '<personname0>', 'tomorrow', 'morning', 'at', '<number0>am']
# ['UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNO ...
# Program: ['<bos>', '(', 'yield', ':output', 'UNKNOWN']
# Expected: ['<bos>', '(', 'yield', ':output', '(', '>', '(', 'size', '(', ':results', '(', 'findeventwrapperwithdefaults', ':constraint', '(', 'eventondatetime', ':datetime', '(', 'dateattimewithdefaults', ':date', '(', 'tomorrow', ')', ':time', '(', 'numberam', ':number', '#', '(', 'number', '<number0>', ')', ')', ')', ':event', '(', 'constraint[event]', ':attendees', '(', 'attendeelisthasrecipientconstraint', ':recipientconstraint', '(', 'recipientwithnamelike', ':constraint', '(', 'constraint[recipient]', ')', ':name', '#', '(', 'personname', '"', '<personname0>', '"', ')', ')', ')', ')', ')', ')', ')', ')', '#', '(', 'number', '0', ')', ')', ')', '<eos>']
# Accuracy: 0.0
# Question: ['when', 'do', 'i', 'have', 'to', 'see', '<personname0>']
# ...
# Program: ['<bos>', '(', 'yield', ':output', 'UNKNOWN']
# Expected: ['<bos>', '(', 'yield', ':output', '(', 'createcommiteventwrapper', ':event', '(', 'createpreflighteventwrapper', ':constraint', '(', 'constraint[event]', ':start', '(', 'constraint[datetime]', ':date', '(', '?=', '(', 'nextdow', ':dow', '#', '(', 'dayofweek', '"', '<dayofweek0>', '"', ')', ')', ')', ')', ':subject', '(', '?=', '#', '(', 'string', '"', '<string0>', 'birthday', 'party', '"', ')', ')', ')', ')', ')', ')', '<eos>']
# Accuracy: 0.0
# Question: ['the', 'second', 'one']
# ['UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNO ...
# Program: ['<bos>', '(', 'yield', ':output', 'UNKNOWN']
# Expected: ['<bos>', '(', 'yield', ':output', '(', 'execute', ':intension', '(', 'choosecreateevent', ':index', '#', '(', 'number', '2', ')', ':intension', '(', 'refer', '(', 'actionintensionconstraint', ')', ')', ')', ')', ')', '<eos>']
# Accuracy: 0.0
# Question: ['thank', 'you']
# ['UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNO ...
# Program: ['<bos>', '(', 'yield', ':output', 'UNKNOWN']
# Expected: ['<bos>', '(', 'pleasantryanythingelsecombined', ')', '<eos>']
# Accuracy: 0.0
# Question: ['do', 'i', 'have', 'any', 'events', 'for', 'this', 'weekend']
# ['UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNOWN', 'UNKNO ...
# Program: ['<bos>', '(', 'yield', ':output', 'UNKNOWN']
# Expected: ['<bos>', '(', 'yield', ':output', '(', '>', '(', 'size', '(', ':results', '(', 'findeventwrapperwithdefaults', ':constraint', '(', 'eventduringrange', ':event', '(', 'constraint[event]', ')', ':range', '(', 'thisweekend', ')', ')', ')', ')', ')', '#', '(', 'number', '0', ')', ')', ')', '<eos>']
# Accuracy: 0.0
# Accuracy: 0.0
